# %%
import pandas as pd
import statistics
import numpy as np
from statistics import mean


exp1_df = pd.read_csv("Experiment1.csv")
exp2_df = pd.read_csv("Experiment2.csv")
exp2_1_df = pd.read_csv("Experiment2_1.csv")
exp3_df = pd.read_csv("Experiment3.csv")
exp3_1_df = pd.read_csv("experiment3_1.csv")
exp3_2_df = pd.read_csv("experiment3_2.csv")
exp3_3_df = pd.read_csv("experiment3_3.csv")
exp4_df = pd.read_csv("Experiment4.csv")
exp4_1_df = pd.read_csv("Experiment4_1.csv")

# %%
rf_acc_means = []
svm_acc_means = []
knn_acc_means = []

rf_acc_std = []
svm_acc_std = []
knn_acc_std = []

rf_happy_means = []
rf_sad_means = []
svm_happy_means = []
svm_sad_means = []
knn_happy_means = []
knn_sad_means = []

rf_happy_stds = []
rf_sad_stds = []
svm_happy_stds = []
svm_sad_stds = []
knn_happy_stds = []
knn_sad_stds = []

# %%
exp1_df
# Out:
#     Subject  Experiment ID Feature extraction Band selection  \
# 0         1              1                  -              -
# 1         1              1                  -              -
# 2         1              1                  -              -
# 3         2              1                  -              -
# 4         2              1                  -              -
# ..      ...            ...                ...            ...
# 91       31              1                  -              -
# 92       31              1                  -              -
# 93       32              1                  -              -
# 94       32              1                  -              -
# 95       32              1                  -              -
#
#    Channel selection Classification algorithm  Accuracy  Happy precision  \
# 0                  -            Random Forest  0.649151         0.576402
# 1                  -                      SVM  0.554145         0.522103
# ...

# %%
rf_acc_arr = []
svm_acc_arr = []
knn_acc_arr = []

rf_happy_arr = []
svm_happy_arr = []
knn_happy_arr = []

rf_sad_arr = []
svm_sad_arr = []
knn_sad_arr = []

exp1_happy = exp1_df['Happy f1-score']
exp1_sad = exp1_df['Sad f1-score']
exp1_acc = exp1_df['Accuracy']

print(len(exp1_acc))
for i in range (0,len(exp1_acc)):
    if (i%3 == 0):
        rf_acc_arr.append(exp1_acc[i])
        rf_happy_arr.append(exp1_happy[i])
        rf_sad_arr.append(exp1_sad[i])
    if (i%3 == 1):
        svm_acc_arr.append(exp1_acc[i])
        svm_happy_arr.append(exp1_happy[i])
        svm_sad_arr.append(exp1_sad[i])
    if (i%3 == 2):
        knn_acc_arr.append(exp1_acc[i])
        knn_happy_arr.append(exp1_happy[i])
        knn_sad_arr.append(exp1_sad[i])



print(rf_acc_arr)
print(svm_acc_arr)
print(knn_acc_arr)
# Out:
# 96
# [0.6491505456349206, 0.7393973214285714, 0.6977616567460317, 0.5998573908730159, 0.7127976190476191, 0.8400452628968254, 0.7237103174603174, 0.6452752976190477, 0.6646515376984127, 0.6701543898809523, 0.7146267361111112, 0.6930183531746031, 0.6071118551587301, 0.6575365823412699, 0.6440042162698413, 0.694397941468254, 0.6744326636904762, 0.7640749007936508, 0.7146577380952381, 0.7449931795634921, 0.6155598958333334, 0.5738622271825397, 0.739195808531746, 0.603484623015873, 0.6666511656746031, 0.6666511656746031, 0.8677765376984127, 0.7097439236111112, 0.6614273313492064, 0.7701357886904762, 0.8391152033730159, 0.6620008680555556]
# ...

# %%
rf_mean = statistics.mean(rf_acc_arr)
print("RF mean: ", rf_mean)
svm_mean = statistics.mean(svm_acc_arr)
print("SVM mean: ", svm_mean)
knn_mean = statistics.mean(knn_acc_arr)
print("kNN mean: ", knn_mean)

rf_acc_means.append(rf_mean)
svm_acc_means.append(svm_mean)
knn_acc_means.append(knn_mean)

rf_std = np.std(rf_acc_arr)
svm_std = np.std(svm_acc_arr)
knn_std = np.std(knn_acc_arr)
print("RF std: ", rf_std)
print("SVM std: ", svm_std)
print("kNN std: ", knn_std)


rf_acc_std.append(rf_std)
svm_acc_std.append(svm_std)
knn_acc_std.append(knn_std)

rf_happy_mean = statistics.mean(rf_happy_arr)
print("RF happy mean: ", rf_happy_mean)
svm_happy_mean = statistics.mean(svm_happy_arr)
print("SVM happy mean: ", svm_happy_mean)
knn_happy_mean = statistics.mean(knn_happy_arr)
print("kNN happy mean: ", knn_happy_mean)

rf_happy_means.append(rf_happy_mean)
svm_happy_means.append(svm_happy_mean)
knn_happy_means.append(knn_happy_mean)

rf_happy_std = np.std(rf_happy_arr)
print("RF happy std: ", rf_happy_std)
svm_happy_std = np.std(svm_happy_arr)
print("SVM happy std: ", svm_happy_std)
knn_happy_std = np.std(knn_happy_arr)
print("kNN happy std: ", knn_happy_std)

rf_happy_stds.append(rf_happy_std)
svm_happy_stds.append(svm_happy_std)
knn_happy_stds.append(knn_happy_std)

rf_sad_mean = statistics.mean(rf_sad_arr)
print("RF sad mean: ", rf_sad_mean)
svm_sad_mean = statistics.mean(svm_sad_arr)
print("SVM sad mean: ", svm_sad_mean)
knn_sad_mean = statistics.mean(knn_sad_arr)
print("kNN sad mean: ", knn_sad_mean)

rf_sad_means.append(rf_sad_mean)
svm_sad_means.append(svm_sad_mean)
knn_sad_means.append(knn_sad_mean)

rf_sad_std = np.std(rf_sad_arr)
print("RF sad std: ", rf_sad_std)
svm_sad_std = np.std(svm_sad_arr)
print("SVM sad std: ", svm_sad_std)
knn_sad_std = np.std(knn_sad_arr)
print("kNN sad std: ", knn_sad_std)

rf_sad_stds.append(rf_sad_std)
svm_sad_stds.append(svm_sad_std)
knn_sad_stds.append(knn_sad_std)
# Out:
# RF mean:  0.6946018763950893
# SVM mean:  0.5506339905753969
# kNN mean:  0.7468891446552579
# RF std:  0.06872420238271855
# SVM std:  0.060163100389985825
# kNN std:  0.06984284913980851
# RF happy mean:  0.7468388440036063
# SVM happy mean:  0.5956643073349047
# kNN happy mean:  0.7697303792876791
# RF happy std:  0.16852015516138472
# SVM happy std:  0.11654534272992265
# kNN happy std:  0.10168562316949993
# RF sad mean:  0.48991004032289187
# SVM sad mean:  0.43970967402422184
# kNN sad mean:  0.6806714436501168
# RF sad std:  0.13095351105026304
# SVM sad std:  0.08517469347458612
# kNN sad std:  0.08091237698693714

# %%
exp2_df
# Out:
#      Subject  Experiment ID Feature extraction Band selection  \
# 0          1              2               STFT          Delta
# 1          1              2               STFT          Delta
# 2          1              2               STFT          Delta
# 3          1              2               STFT          Theta
# 4          1              2               STFT          Theta
# ..       ...            ...                ...            ...
# 460       32              2               STFT           Beta
# 461       32              2               STFT           Beta
# 462       32              2               STFT          Gamma
# 463       32              2               STFT          Gamma
# 464       32              2               STFT          Gamma
#
#     Channel selection Classification algorithm  Accuracy  Happy precision  \
# 0                   -            Random Forest  0.833984         0.937500
# ...

# %%
'''
rf_acc_arr_delta = []
svm_acc_arr_delta = []
knn_acc_arr_delta = []
rf_acc_arr_theta = []
svm_acc_arr_theta = []
knn_acc_arr_theta = []
rf_acc_arr_alpha = []
svm_acc_arr_alpha = []
knn_acc_arr_alpha = []
rf_acc_arr_beta = []
svm_acc_arr_beta = []
knn_acc_arr_beta = []
rf_acc_arr_gamma = []
svm_acc_arr_gamma = []
knn_acc_arr_gamma = []

rf_happy_arr_delta = []
svm_happy_arr_delta = []
knn_happy_arr_delta = []
rf_happy_arr_theta = []
svm_happy_arr_theta = []
knn_happy_arr_theta = []
rf_happy_arr_alpha = []
svm_happy_arr_alpha = []
knn_happy_arr_alpha = []
rf_happy_arr_beta = []
svm_happy_arr_beta = []
knn_happy_arr_beta = []
rf_happy_arr_gamma = []
svm_happy_arr_gamma = []
knn_happy_arr_gamma = []

rf_sad_arr_delta = []
svm_sad_arr_delta = []
knn_sad_arr_delta = []
rf_sad_arr_theta = []
svm_sad_arr_theta = []
knn_sad_arr_theta = []
rf_sad_arr_alpha = []
svm_sad_arr_alpha = []
knn_sad_arr_alpha = []
rf_sad_arr_beta = []
svm_sad_arr_beta = []
knn_sad_arr_beta = []
rf_sad_arr_gamma = []
svm_sad_arr_gamma = []
knn_sad_arr_gamma = []

exp2_acc = exp2_df['Accuracy']
exp2_happy = exp2_df['Happy f1-score']
exp2_sad = exp2_df['Sad f1-score']

print(len(exp2_acc))
for i in range (0,len(exp2_acc)):
    if (i%15 == 0):
        rf_acc_arr_delta.append(exp2_acc[i])
        rf_happy_arr_delta.append(exp2_happy[i])
        rf_sad_arr_delta.append(exp2_sad[i])
    if (i%15 == 1):
        svm_acc_arr_delta.append(exp2_acc[i])
        svm_happy_arr_delta.append(exp2_happy[i])
        svm_sad_arr_delta.append(exp2_sad[i])
    if (i%15 == 2):
        knn_acc_arr_delta.append(exp2_acc[i])
        knn_happy_arr_delta.append(exp2_happy[i])
        knn_sad_arr_delta.append(exp2_sad[i])
    if (i%15 == 3):
        rf_acc_arr_theta.append(exp2_acc[i])
        rf_happy_arr_theta.append(exp2_happy[i])
        rf_sad_arr_theta.append(exp2_sad[i])
    if (i%15 == 4):
        svm_acc_arr_theta.append(exp2_acc[i])
        svm_happy_arr_theta.append(exp2_happy[i])
        svm_sad_arr_theta.append(exp2_sad[i])
    if (i%15 == 5):
        knn_acc_arr_theta.append(exp2_acc[i])
        knn_happy_arr_theta.append(exp2_happy[i])
        knn_sad_arr_theta.append(exp2_sad[i])
    if (i%15 == 6):
        rf_acc_arr_alpha.append(exp2_acc[i])
        rf_happy_arr_alpha.append(exp2_happy[i])
        rf_sad_arr_alpha.append(exp2_sad[i])
    if (i%15 == 7):
        svm_acc_arr_alpha.append(exp2_acc[i])
        svm_happy_arr_alpha.append(exp2_happy[i])
        svm_sad_arr_alpha.append(exp2_sad[i])
    if (i%15 == 8):
        knn_acc_arr_alpha.append(exp2_acc[i])
        knn_happy_arr_alpha.append(exp2_happy[i])
        knn_sad_arr_alpha.append(exp2_sad[i])
    if (i%15 == 9):
        rf_acc_arr_beta.append(exp2_acc[i])
        rf_happy_arr_beta.append(exp2_happy[i])
        rf_sad_arr_beta.append(exp2_sad[i])
    if (i%15 == 10):
        svm_acc_arr_beta.append(exp2_acc[i])
        svm_happy_arr_beta.append(exp2_happy[i])
        svm_sad_arr_beta.append(exp2_sad[i])
    if (i%15 == 11):
        knn_acc_arr_beta.append(exp2_acc[i])
        knn_happy_arr_beta.append(exp2_happy[i])
        knn_sad_arr_beta.append(exp2_sad[i])
    if (i%15 == 12):
        rf_acc_arr_gamma.append(exp2_acc[i])
        rf_happy_arr_gamma.append(exp2_happy[i])
        rf_sad_arr_gamma.append(exp2_sad[i])
    if (i%15 == 13):
        svm_acc_arr_gamma.append(exp2_acc[i])
        svm_happy_arr_gamma.append(exp2_happy[i])
        svm_sad_arr_gamma.append(exp2_sad[i])
    if (i%15 == 14):
        knn_acc_arr_gamma.append(exp2_acc[i])
        knn_happy_arr_gamma.append(exp2_happy[i])
        knn_sad_arr_gamma.append(exp2_sad[i])
rf_mean_delta = statistics.mean(rf_acc_arr_delta)
print("RF mean delta: ", rf_mean_delta)
svm_mean_delta = statistics.mean(svm_acc_arr_delta)
print("SVM mean delta: ", svm_mean_delta)
knn_mean_delta = statistics.mean(knn_acc_arr_delta)
print("kNN mean delta: ",knn_mean_delta)

rf_mean_theta = statistics.mean(rf_acc_arr_theta)
print("RF mean theta: ", rf_mean_theta)
svm_mean_theta = statistics.mean(svm_acc_arr_theta)
print("SVM mean theta: ", svm_mean_theta)
knn_mean_theta = statistics.mean(knn_acc_arr_theta)
print("kNN mean theta: ",knn_mean_theta)

rf_mean_alpha = statistics.mean(rf_acc_arr_alpha)
print("RF mean alpha: ", rf_mean_alpha)
svm_mean_alpha = statistics.mean(svm_acc_arr_alpha)
print("SVM mean alpha: ", svm_mean_alpha)
knn_mean_alpha = statistics.mean(knn_acc_arr_alpha)
print("kNN mean alpha: ",knn_mean_alpha)

rf_mean_beta = statistics.mean(rf_acc_arr_beta)
print("RF mean beta: ", rf_mean_beta)
svm_mean_beta = statistics.mean(svm_acc_arr_beta)
print("SVM mean beta: ", svm_mean_beta)
knn_mean_beta = statistics.mean(knn_acc_arr_beta)
print("kNN mean beta: ",knn_mean_beta)

rf_mean_gamma = statistics.mean(rf_acc_arr_gamma)
print("RF mean gamma: ", rf_mean_gamma)
svm_mean_gamma = statistics.mean(svm_acc_arr_gamma)
print("SVM mean gamma: ", svm_mean_gamma)
knn_mean_gamma = statistics.mean(knn_acc_arr_gamma)
print("kNN mean gamma: ",knn_mean_gamma)

rf_acc_means.append(rf_mean_delta)
rf_acc_means.append(rf_mean_theta)
rf_acc_means.append(rf_mean_alpha)
rf_acc_means.append(rf_mean_beta)
rf_acc_means.append(rf_mean_gamma)

svm_acc_means.append(svm_mean_delta)
svm_acc_means.append(svm_mean_theta)
svm_acc_means.append(svm_mean_alpha)
svm_acc_means.append(svm_mean_beta)
svm_acc_means.append(svm_mean_gamma)

knn_acc_means.append(knn_mean_delta)
knn_acc_means.append(knn_mean_theta)
knn_acc_means.append(knn_mean_alpha)
knn_acc_means.append(knn_mean_beta)
knn_acc_means.append(knn_mean_gamma)

rf_delta_std = np.std(rf_acc_arr_delta)
rf_theta_std = np.std(rf_acc_arr_theta)
rf_alpha_std = np.std(rf_acc_arr_alpha)
rf_beta_std = np.std(rf_acc_arr_beta)
rf_gamma_std = np.std(rf_acc_arr_gamma)

svm_delta_std = np.std(svm_acc_arr_delta)
svm_theta_std = np.std(svm_acc_arr_theta)
svm_alpha_std = np.std(svm_acc_arr_alpha)
svm_beta_std = np.std(svm_acc_arr_beta)
svm_gamma_std = np.std(svm_acc_arr_gamma)

knn_delta_std = np.std(knn_acc_arr_delta)
knn_theta_std = np.std(knn_acc_arr_theta)
knn_alpha_std = np.std(knn_acc_arr_alpha)
knn_beta_std = np.std(knn_acc_arr_beta)
knn_gamma_std = np.std(knn_acc_arr_gamma)

rf_acc_std.append(rf_delta_std)
rf_acc_std.append(rf_theta_std)
rf_acc_std.append(rf_alpha_std)
rf_acc_std.append(rf_beta_std)
rf_acc_std.append(rf_gamma_std)

svm_acc_std.append(svm_delta_std)
svm_acc_std.append(svm_theta_std)
svm_acc_std.append(svm_alpha_std)
svm_acc_std.append(svm_beta_std)
svm_acc_std.append(svm_gamma_std)

knn_acc_std.append(knn_delta_std)
knn_acc_std.append(knn_theta_std)
knn_acc_std.append(knn_alpha_std)
knn_acc_std.append(knn_beta_std)
knn_acc_std.append(knn_gamma_std)

rf_happy_delta = statistics.mean(rf_happy_arr_delta)
print("RF happy delta: ", rf_happy_delta)
svm_happy_delta = statistics.mean(svm_happy_arr_delta)
print("SVM happy delta: ", svm_happy_delta)
knn_happy_delta = statistics.mean(knn_happy_arr_delta)
print("kNN happy delta: ",knn_happy_delta)

rf_happy_theta = statistics.mean(rf_happy_arr_theta)
print("RF happy theta: ", rf_happy_theta)
svm_happy_theta = statistics.mean(svm_happy_arr_theta)
print("SVM happy theta: ", svm_happy_theta)
knn_happy_theta = statistics.mean(knn_happy_arr_theta)
print("kNN happy theta: ",knn_happy_theta)

rf_happy_alpha = statistics.mean(rf_happy_arr_alpha)
print("RF happy alpha: ", rf_happy_alpha)
svm_happy_alpha = statistics.mean(svm_happy_arr_alpha)
print("SVM happy alpha: ", svm_happy_alpha)
knn_happy_alpha = statistics.mean(knn_happy_arr_alpha)
print("kNN happy alpha: ",knn_happy_alpha)

rf_happy_beta = statistics.mean(rf_happy_arr_beta)
print("RF happy beta: ", rf_happy_beta)
svm_happy_beta = statistics.mean(svm_happy_arr_beta)
print("SVM happy beta: ", svm_happy_beta)
knn_happy_beta = statistics.mean(knn_happy_arr_beta)
print("kNN happy beta: ",knn_happy_beta)

rf_happy_gamma = statistics.mean(rf_happy_arr_gamma)
print("RF happy gamma: ", rf_happy_gamma)
svm_happy_gamma = statistics.mean(svm_happy_arr_gamma)
print("SVM happy gamma: ", svm_happy_gamma)
knn_happy_gamma = statistics.mean(knn_happy_arr_gamma)
print("kNN happy gamma: ",knn_happy_gamma)

rf_happy_means.append(rf_happy_delta)
rf_happy_means.append(rf_happy_theta)
rf_happy_means.append(rf_happy_alpha)
rf_happy_means.append(rf_happy_beta)
rf_happy_means.append(rf_happy_gamma)

svm_happy_means.append(svm_happy_delta)
svm_happy_means.append(svm_happy_theta)
svm_happy_means.append(svm_happy_alpha)
svm_happy_means.append(svm_happy_beta)
svm_happy_means.append(svm_happy_gamma)

knn_happy_means.append(knn_happy_delta)
knn_happy_means.append(knn_happy_theta)
knn_happy_means.append(knn_happy_alpha)
knn_happy_means.append(knn_happy_beta)
knn_happy_means.append(knn_happy_gamma)

rf_sad_delta = statistics.mean(rf_sad_arr_delta)
print("RF sad delta: ", rf_sad_delta)
svm_sad_delta = statistics.mean(svm_sad_arr_delta)
print("SVM sad delta: ", svm_sad_delta)
knn_sad_delta = statistics.mean(knn_sad_arr_delta)
print("kNN sad delta: ",knn_sad_delta)

rf_sad_theta = statistics.mean(rf_sad_arr_theta)
print("RF sad theta: ", rf_sad_theta)
svm_sad_theta = statistics.mean(svm_sad_arr_theta)
print("SVM sad theta: ", svm_sad_theta)
knn_sad_theta = statistics.mean(knn_sad_arr_theta)
print("kNN sad theta: ",knn_sad_theta)

rf_sad_alpha = statistics.mean(rf_sad_arr_alpha)
print("RF sad alpha: ", rf_sad_alpha)
svm_sad_alpha = statistics.mean(svm_sad_arr_alpha)
print("SVM sad alpha: ", svm_sad_alpha)
knn_sad_alpha = statistics.mean(knn_sad_arr_alpha)
print("kNN sad alpha: ",knn_sad_alpha)

rf_sad_beta = statistics.mean(rf_sad_arr_beta)
print("RF sad beta: ", rf_sad_beta)
svm_sad_beta = statistics.mean(svm_sad_arr_beta)
print("SVM sad beta: ", svm_sad_beta)
knn_sad_beta = statistics.mean(knn_sad_arr_beta)
print("kNN sad beta: ",knn_sad_beta)

rf_sad_gamma = statistics.mean(rf_sad_arr_gamma)
print("RF sad gamma: ", rf_sad_gamma)
svm_sad_gamma = statistics.mean(svm_sad_arr_gamma)
print("SVM sad gamma: ", svm_sad_gamma)
knn_sad_gamma = statistics.mean(knn_sad_arr_gamma)
print("kNN sad gamma: ",knn_sad_gamma)

rf_sad_means.append(rf_sad_delta)
rf_sad_means.append(rf_sad_theta)
rf_sad_means.append(rf_sad_alpha)
rf_sad_means.append(rf_sad_beta)
rf_sad_means.append(rf_sad_gamma)

svm_sad_means.append(svm_sad_delta)
svm_sad_means.append(svm_sad_theta)
svm_sad_means.append(svm_sad_alpha)
svm_sad_means.append(svm_sad_beta)
svm_sad_means.append(svm_sad_gamma)

knn_sad_means.append(knn_sad_delta)
knn_sad_means.append(knn_sad_theta)
knn_sad_means.append(knn_sad_alpha)
knn_sad_means.append(knn_sad_beta)
knn_sad_means.append(knn_sad_gamma)
'''
# Out:
# '\nrf_acc_arr_delta = []\nsvm_acc_arr_delta = []\nknn_acc_arr_delta = []\nrf_acc_arr_theta = []\nsvm_acc_arr_theta = []\nknn_acc_arr_theta = []\nrf_acc_arr_alpha = []\nsvm_acc_arr_alpha = []\nknn_acc_arr_alpha = []\nrf_acc_arr_beta = []\nsvm_acc_arr_beta = []\nknn_acc_arr_beta = []\nrf_acc_arr_gamma = []\nsvm_acc_arr_gamma = []\nknn_acc_arr_gamma = []\n\nrf_happy_arr_delta = []\nsvm_happy_arr_delta = []\nknn_happy_arr_delta = []\nrf_happy_arr_theta = []\nsvm_happy_arr_theta = []\nknn_happy_arr_theta = []\nrf_happy_arr_alpha = []\nsvm_happy_arr_alpha = []\nknn_happy_arr_alpha = []\nrf_happy_arr_beta = []\nsvm_happy_arr_beta = []\nknn_happy_arr_beta = []\nrf_happy_arr_gamma = []\nsvm_happy_arr_gamma = []\nknn_happy_arr_gamma = []\n\nrf_sad_arr_delta = []\nsvm_sad_arr_delta = []\nknn_sad_arr_delta = []\nrf_sad_arr_theta = []\nsvm_sad_arr_theta = []\nknn_sad_arr_theta = []\nrf_sad_arr_alpha = []\nsvm_sad_arr_alpha = []\nknn_sad_arr_alpha = []\nrf_sad_arr_beta = []\nsvm_sad_arr_beta = []\
# ...

# %%
rf_acc_arr_delta = []
svm_acc_arr_delta = []
knn_acc_arr_delta = []
rf_acc_arr_theta = []
svm_acc_arr_theta = []
knn_acc_arr_theta = []
rf_acc_arr_alpha = []
svm_acc_arr_alpha = []
knn_acc_arr_alpha = []
rf_acc_arr_beta = []
svm_acc_arr_beta = []
knn_acc_arr_beta = []
rf_acc_arr_gamma = []
svm_acc_arr_gamma = []
knn_acc_arr_gamma = []

rf_happy_arr_delta = []
svm_happy_arr_delta = []
knn_happy_arr_delta = []
rf_happy_arr_theta = []
svm_happy_arr_theta = []
knn_happy_arr_theta = []
rf_happy_arr_alpha = []
svm_happy_arr_alpha = []
knn_happy_arr_alpha = []
rf_happy_arr_beta = []
svm_happy_arr_beta = []
knn_happy_arr_beta = []
rf_happy_arr_gamma = []
svm_happy_arr_gamma = []
knn_happy_arr_gamma = []

rf_sad_arr_delta = []
svm_sad_arr_delta = []
knn_sad_arr_delta = []
rf_sad_arr_theta = []
svm_sad_arr_theta = []
knn_sad_arr_theta = []
rf_sad_arr_alpha = []
svm_sad_arr_alpha = []
knn_sad_arr_alpha = []
rf_sad_arr_beta = []
svm_sad_arr_beta = []
knn_sad_arr_beta = []
rf_sad_arr_gamma = []
svm_sad_arr_gamma = []
knn_sad_arr_gamma = []

exp2_acc = exp2_1_df['Accuracy']
exp2_happy = exp2_1_df['Happy f1-score']
exp2_sad = exp2_1_df['Sad f1-score']

print(len(exp2_acc))
for i in range (0,len(exp2_acc)):
    if (i%15 == 0):
        rf_acc_arr_delta.append(exp2_acc[i])
        rf_happy_arr_delta.append(exp2_happy[i])
        rf_sad_arr_delta.append(exp2_sad[i])
    if (i%15 == 1):
        svm_acc_arr_delta.append(exp2_acc[i])
        svm_happy_arr_delta.append(exp2_happy[i])
        svm_sad_arr_delta.append(exp2_sad[i])
    if (i%15 == 2):
        knn_acc_arr_delta.append(exp2_acc[i])
        knn_happy_arr_delta.append(exp2_happy[i])
        knn_sad_arr_delta.append(exp2_sad[i])
    if (i%15 == 3):
        rf_acc_arr_theta.append(exp2_acc[i])
        rf_happy_arr_theta.append(exp2_happy[i])
        rf_sad_arr_theta.append(exp2_sad[i])
    if (i%15 == 4):
        svm_acc_arr_theta.append(exp2_acc[i])
        svm_happy_arr_theta.append(exp2_happy[i])
        svm_sad_arr_theta.append(exp2_sad[i])
    if (i%15 == 5):
        knn_acc_arr_theta.append(exp2_acc[i])
        knn_happy_arr_theta.append(exp2_happy[i])
        knn_sad_arr_theta.append(exp2_sad[i])
    if (i%15 == 6):
        rf_acc_arr_alpha.append(exp2_acc[i])
        rf_happy_arr_alpha.append(exp2_happy[i])
        rf_sad_arr_alpha.append(exp2_sad[i])
    if (i%15 == 7):
        svm_acc_arr_alpha.append(exp2_acc[i])
        svm_happy_arr_alpha.append(exp2_happy[i])
        svm_sad_arr_alpha.append(exp2_sad[i])
    if (i%15 == 8):
        knn_acc_arr_alpha.append(exp2_acc[i])
        knn_happy_arr_alpha.append(exp2_happy[i])
        knn_sad_arr_alpha.append(exp2_sad[i])
    if (i%15 == 9):
        rf_acc_arr_beta.append(exp2_acc[i])
        rf_happy_arr_beta.append(exp2_happy[i])
        rf_sad_arr_beta.append(exp2_sad[i])
    if (i%15 == 10):
        svm_acc_arr_beta.append(exp2_acc[i])
        svm_happy_arr_beta.append(exp2_happy[i])
        svm_sad_arr_beta.append(exp2_sad[i])
    if (i%15 == 11):
        knn_acc_arr_beta.append(exp2_acc[i])
        knn_happy_arr_beta.append(exp2_happy[i])
        knn_sad_arr_beta.append(exp2_sad[i])
    if (i%15 == 12):
        rf_acc_arr_gamma.append(exp2_acc[i])
        rf_happy_arr_gamma.append(exp2_happy[i])
        rf_sad_arr_gamma.append(exp2_sad[i])
    if (i%15 == 13):
        svm_acc_arr_gamma.append(exp2_acc[i])
        svm_happy_arr_gamma.append(exp2_happy[i])
        svm_sad_arr_gamma.append(exp2_sad[i])
    if (i%15 == 14):
        knn_acc_arr_gamma.append(exp2_acc[i])
        knn_happy_arr_gamma.append(exp2_happy[i])
        knn_sad_arr_gamma.append(exp2_sad[i])

rf_mean_delta = statistics.mean(rf_acc_arr_delta)
print("RF mean delta: ", rf_mean_delta)
svm_mean_delta = statistics.mean(svm_acc_arr_delta)
print("SVM mean delta: ", svm_mean_delta)
knn_mean_delta = statistics.mean(knn_acc_arr_delta)
print("kNN mean delta: ",knn_mean_delta)

rf_mean_theta = statistics.mean(rf_acc_arr_theta)
print("RF mean theta: ", rf_mean_theta)
svm_mean_theta = statistics.mean(svm_acc_arr_theta)
print("SVM mean theta: ", svm_mean_theta)
knn_mean_theta = statistics.mean(knn_acc_arr_theta)
print("kNN mean theta: ",knn_mean_theta)

rf_mean_alpha = statistics.mean(rf_acc_arr_alpha)
print("RF mean alpha: ", rf_mean_alpha)
svm_mean_alpha = statistics.mean(svm_acc_arr_alpha)
print("SVM mean alpha: ", svm_mean_alpha)
knn_mean_alpha = statistics.mean(knn_acc_arr_alpha)
print("kNN mean alpha: ",knn_mean_alpha)

rf_mean_beta = statistics.mean(rf_acc_arr_beta)
print("RF mean beta: ", rf_mean_beta)
svm_mean_beta = statistics.mean(svm_acc_arr_beta)
print("SVM mean beta: ", svm_mean_beta)
knn_mean_beta = statistics.mean(knn_acc_arr_beta)
print("kNN mean beta: ",knn_mean_beta)

rf_mean_gamma = statistics.mean(rf_acc_arr_gamma)
print("RF mean gamma: ", rf_mean_gamma)
svm_mean_gamma = statistics.mean(svm_acc_arr_gamma)
print("SVM mean gamma: ", svm_mean_gamma)
knn_mean_gamma = statistics.mean(knn_acc_arr_gamma)
print("kNN mean gamma: ",knn_mean_gamma)

rf_acc_means.append(rf_mean_delta)
rf_acc_means.append(rf_mean_theta)
rf_acc_means.append(rf_mean_alpha)
rf_acc_means.append(rf_mean_beta)
rf_acc_means.append(rf_mean_gamma)

svm_acc_means.append(svm_mean_delta)
svm_acc_means.append(svm_mean_theta)
svm_acc_means.append(svm_mean_alpha)
svm_acc_means.append(svm_mean_beta)
svm_acc_means.append(svm_mean_gamma)

knn_acc_means.append(knn_mean_delta)
knn_acc_means.append(knn_mean_theta)
knn_acc_means.append(knn_mean_alpha)
knn_acc_means.append(knn_mean_beta)
knn_acc_means.append(knn_mean_gamma)

rf_delta_std = np.std(rf_acc_arr_delta)
rf_theta_std = np.std(rf_acc_arr_theta)
rf_alpha_std = np.std(rf_acc_arr_alpha)
rf_beta_std = np.std(rf_acc_arr_beta)
rf_gamma_std = np.std(rf_acc_arr_gamma)

svm_delta_std = np.std(svm_acc_arr_delta)
svm_theta_std = np.std(svm_acc_arr_theta)
svm_alpha_std = np.std(svm_acc_arr_alpha)
svm_beta_std = np.std(svm_acc_arr_beta)
svm_gamma_std = np.std(svm_acc_arr_gamma)

knn_delta_std = np.std(knn_acc_arr_delta)
knn_theta_std = np.std(knn_acc_arr_theta)
knn_alpha_std = np.std(knn_acc_arr_alpha)
knn_beta_std = np.std(knn_acc_arr_beta)
knn_gamma_std = np.std(knn_acc_arr_gamma)

rf_acc_std.append(rf_delta_std)
rf_acc_std.append(rf_theta_std)
rf_acc_std.append(rf_alpha_std)
rf_acc_std.append(rf_beta_std)
rf_acc_std.append(rf_gamma_std)

svm_acc_std.append(svm_delta_std)
svm_acc_std.append(svm_theta_std)
svm_acc_std.append(svm_alpha_std)
svm_acc_std.append(svm_beta_std)
svm_acc_std.append(svm_gamma_std)

knn_acc_std.append(knn_delta_std)
knn_acc_std.append(knn_theta_std)
knn_acc_std.append(knn_alpha_std)
knn_acc_std.append(knn_beta_std)
knn_acc_std.append(knn_gamma_std)

rf_happy_delta = statistics.mean(rf_happy_arr_delta)
print("RF happy delta: ", rf_happy_delta)
svm_happy_delta = statistics.mean(svm_happy_arr_delta)
print("SVM happy delta: ", svm_happy_delta)
knn_happy_delta = statistics.mean(knn_happy_arr_delta)
print("kNN happy delta: ",knn_happy_delta)

rf_happy_theta = statistics.mean(rf_happy_arr_theta)
print("RF happy theta: ", rf_happy_theta)
svm_happy_theta = statistics.mean(svm_happy_arr_theta)
print("SVM happy theta: ", svm_happy_theta)
knn_happy_theta = statistics.mean(knn_happy_arr_theta)
print("kNN happy theta: ",knn_happy_theta)

rf_happy_alpha = statistics.mean(rf_happy_arr_alpha)
print("RF happy alpha: ", rf_happy_alpha)
svm_happy_alpha = statistics.mean(svm_happy_arr_alpha)
print("SVM happy alpha: ", svm_happy_alpha)
knn_happy_alpha = statistics.mean(knn_happy_arr_alpha)
print("kNN happy alpha: ",knn_happy_alpha)

rf_happy_beta = statistics.mean(rf_happy_arr_beta)
print("RF happy beta: ", rf_happy_beta)
svm_happy_beta = statistics.mean(svm_happy_arr_beta)
print("SVM happy beta: ", svm_happy_beta)
knn_happy_beta = statistics.mean(knn_happy_arr_beta)
print("kNN happy beta: ",knn_happy_beta)

rf_happy_gamma = statistics.mean(rf_happy_arr_gamma)
print("RF happy gamma: ", rf_happy_gamma)
svm_happy_gamma = statistics.mean(svm_happy_arr_gamma)
print("SVM happy gamma: ", svm_happy_gamma)
knn_happy_gamma = statistics.mean(knn_happy_arr_gamma)
print("kNN happy gamma: ",knn_happy_gamma)

rf_happy_means.append(rf_happy_delta)
rf_happy_means.append(rf_happy_theta)
rf_happy_means.append(rf_happy_alpha)
rf_happy_means.append(rf_happy_beta)
rf_happy_means.append(rf_happy_gamma)

svm_happy_means.append(svm_happy_delta)
svm_happy_means.append(svm_happy_theta)
svm_happy_means.append(svm_happy_alpha)
svm_happy_means.append(svm_happy_beta)
svm_happy_means.append(svm_happy_gamma)

knn_happy_means.append(knn_happy_delta)
knn_happy_means.append(knn_happy_theta)
knn_happy_means.append(knn_happy_alpha)
knn_happy_means.append(knn_happy_beta)
knn_happy_means.append(knn_happy_gamma)

rf_happy_delta = np.std(rf_happy_arr_delta)
print("RF happy delta: ", rf_happy_delta)
svm_happy_delta = np.std(svm_happy_arr_delta)
print("SVM happy delta: ", svm_happy_delta)
knn_happy_delta = np.std(knn_happy_arr_delta)
print("kNN happy delta: ",knn_happy_delta)

rf_happy_theta = np.std(rf_happy_arr_theta)
print("RF happy theta: ", rf_happy_theta)
svm_happy_theta = np.std(svm_happy_arr_theta)
print("SVM happy theta: ", svm_happy_theta)
knn_happy_theta = np.std(knn_happy_arr_theta)
print("kNN happy theta: ",knn_happy_theta)

rf_happy_alpha = np.std(rf_happy_arr_alpha)
print("RF happy alpha: ", rf_happy_alpha)
svm_happy_alpha = np.std(svm_happy_arr_alpha)
print("SVM happy alpha: ", svm_happy_alpha)
knn_happy_alpha = np.std(knn_happy_arr_alpha)
print("kNN happy alpha: ",knn_happy_alpha)

rf_happy_beta = np.std(rf_happy_arr_beta)
print("RF happy beta: ", rf_happy_beta)
svm_happy_beta = np.std(svm_happy_arr_beta)
print("SVM happy beta: ", svm_happy_beta)
knn_happy_beta = np.std(knn_happy_arr_beta)
print("kNN happy beta: ",knn_happy_beta)

rf_happy_gamma = np.std(rf_happy_arr_gamma)
print("RF happy gamma: ", rf_happy_gamma)
svm_happy_gamma = np.std(svm_happy_arr_gamma)
print("SVM happy gamma: ", svm_happy_gamma)
knn_happy_gamma = np.std(knn_happy_arr_gamma)
print("kNN happy gamma: ",knn_happy_gamma)

rf_happy_stds.append(rf_happy_delta)
rf_happy_stds.append(rf_happy_theta)
rf_happy_stds.append(rf_happy_alpha)
rf_happy_stds.append(rf_happy_beta)
rf_happy_stds.append(rf_happy_gamma)

svm_happy_stds.append(svm_happy_delta)
svm_happy_stds.append(svm_happy_theta)
svm_happy_stds.append(svm_happy_alpha)
svm_happy_stds.append(svm_happy_beta)
svm_happy_stds.append(svm_happy_gamma)

knn_happy_stds.append(knn_happy_delta)
knn_happy_stds.append(knn_happy_theta)
knn_happy_stds.append(knn_happy_alpha)
knn_happy_stds.append(knn_happy_beta)
knn_happy_stds.append(knn_happy_gamma)

rf_sad_delta = statistics.mean(rf_sad_arr_delta)
print("RF sad delta: ", rf_sad_delta)
svm_sad_delta = statistics.mean(svm_sad_arr_delta)
print("SVM sad delta: ", svm_sad_delta)
knn_sad_delta = statistics.mean(knn_sad_arr_delta)
print("kNN sad delta: ",knn_sad_delta)

rf_sad_theta = statistics.mean(rf_sad_arr_theta)
print("RF sad theta: ", rf_sad_theta)
svm_sad_theta = statistics.mean(svm_sad_arr_theta)
print("SVM sad theta: ", svm_sad_theta)
knn_sad_theta = statistics.mean(knn_sad_arr_theta)
print("kNN sad theta: ",knn_sad_theta)

rf_sad_alpha = statistics.mean(rf_sad_arr_alpha)
print("RF sad alpha: ", rf_sad_alpha)
svm_sad_alpha = statistics.mean(svm_sad_arr_alpha)
print("SVM sad alpha: ", svm_sad_alpha)
knn_sad_alpha = statistics.mean(knn_sad_arr_alpha)
print("kNN sad alpha: ",knn_sad_alpha)

rf_sad_beta = statistics.mean(rf_sad_arr_beta)
print("RF sad beta: ", rf_sad_beta)
svm_sad_beta = statistics.mean(svm_sad_arr_beta)
print("SVM sad beta: ", svm_sad_beta)
knn_sad_beta = statistics.mean(knn_sad_arr_beta)
print("kNN sad beta: ",knn_sad_beta)

rf_sad_gamma = statistics.mean(rf_sad_arr_gamma)
print("RF sad gamma: ", rf_sad_gamma)
svm_sad_gamma = statistics.mean(svm_sad_arr_gamma)
print("SVM sad gamma: ", svm_sad_gamma)
knn_sad_gamma = statistics.mean(knn_sad_arr_gamma)
print("kNN sad gamma: ",knn_sad_gamma)

rf_sad_means.append(rf_sad_delta)
rf_sad_means.append(rf_sad_theta)
rf_sad_means.append(rf_sad_alpha)
rf_sad_means.append(rf_sad_beta)
rf_sad_means.append(rf_sad_gamma)

svm_sad_means.append(svm_sad_delta)
svm_sad_means.append(svm_sad_theta)
svm_sad_means.append(svm_sad_alpha)
svm_sad_means.append(svm_sad_beta)
svm_sad_means.append(svm_sad_gamma)

knn_sad_means.append(knn_sad_delta)
knn_sad_means.append(knn_sad_theta)
knn_sad_means.append(knn_sad_alpha)
knn_sad_means.append(knn_sad_beta)
knn_sad_means.append(knn_sad_gamma)

rf_sad_delta = np.std(rf_sad_arr_delta)
print("RF sad delta: ", rf_sad_delta)
svm_sad_delta = np.std(svm_sad_arr_delta)
print("SVM sad delta: ", svm_sad_delta)
knn_sad_delta = np.std(knn_sad_arr_delta)
print("kNN sad delta: ",knn_sad_delta)

rf_sad_theta = np.std(rf_sad_arr_theta)
print("RF sad theta: ", rf_sad_theta)
svm_sad_theta = np.std(svm_sad_arr_theta)
print("SVM sad theta: ", svm_sad_theta)
knn_sad_theta = np.std(knn_sad_arr_theta)
print("kNN sad theta: ",knn_sad_theta)

rf_sad_alpha = np.std(rf_sad_arr_alpha)
print("RF sad alpha: ", rf_sad_alpha)
svm_sad_alpha = np.std(svm_sad_arr_alpha)
print("SVM sad alpha: ", svm_sad_alpha)
knn_sad_alpha = np.std(knn_sad_arr_alpha)
print("kNN sad alpha: ",knn_sad_alpha)

rf_sad_beta = np.std(rf_sad_arr_beta)
print("RF sad beta: ", rf_sad_beta)
svm_sad_beta = np.std(svm_sad_arr_beta)
print("SVM sad beta: ", svm_sad_beta)
knn_sad_beta = np.std(knn_sad_arr_beta)
print("kNN sad beta: ",knn_sad_beta)

rf_sad_gamma = np.std(rf_sad_arr_gamma)
print("RF sad gamma: ", rf_sad_gamma)
svm_sad_gamma = np.std(svm_sad_arr_gamma)
print("SVM sad gamma: ", svm_sad_gamma)
knn_sad_gamma = np.std(knn_sad_arr_gamma)
print("kNN sad gamma: ",knn_sad_gamma)

rf_sad_stds.append(rf_sad_delta)
rf_sad_stds.append(rf_sad_theta)
rf_sad_stds.append(rf_sad_alpha)
rf_sad_stds.append(rf_sad_beta)
rf_sad_stds.append(rf_sad_gamma)

svm_sad_stds.append(svm_sad_delta)
svm_sad_stds.append(svm_sad_theta)
svm_sad_stds.append(svm_sad_alpha)
svm_sad_stds.append(svm_sad_beta)
svm_sad_stds.append(svm_sad_gamma)

knn_sad_stds.append(knn_sad_delta)
knn_sad_stds.append(knn_sad_theta)
knn_sad_stds.append(knn_sad_alpha)
knn_sad_stds.append(knn_sad_beta)
knn_sad_stds.append(knn_sad_gamma)
# Out:
# 480
# RF mean delta:  0.95684814453125
# SVM mean delta:  0.6380615234375
# kNN mean delta:  0.94818115234375
# RF mean theta:  0.955078125
# SVM mean theta:  0.70361328125
# kNN mean theta:  0.9493408203125
# RF mean alpha:  0.9549560546875
# SVM mean alpha:  0.7491455078125
# kNN mean alpha:  0.94964599609375
# RF mean beta:  0.95391845703125
# SVM mean beta:  0.9442138671875
# kNN mean beta:  0.94903564453125
# RF mean gamma:  0.9541015625
# SVM mean gamma:  0.9342041015625
# kNN mean gamma:  0.95196533203125
# RF happy delta:  0.9587528689180729
# SVM happy delta:  0.6439138947821894
# kNN happy delta:  0.9509217448737153
# RF happy theta:  0.957357563317586
# SVM happy theta:  0.7223230763803202
# kNN happy theta:  0.9519689884256634
# RF happy alpha:  0.9572922195129095
# SVM happy alpha:  0.7650968437512448
# kNN happy alpha:  0.9519855050903034
# RF happy beta:  0.9562650437812578
# SVM happy beta:  0.9451008067842712
# kNN happy beta:  0.9521729212274461
# ...

# %%
exp3_df
# Out:
#     Subject  Experiment ID Feature extraction Band selection  \
# 0         1              3               STFT      All bands
# 1         1              3               STFT      All bands
# 2         1              3               STFT      All bands
# 3         2              3               STFT      All bands
# 4         2              3               STFT      All bands
# ..      ...            ...                ...            ...
# 91       31              3               STFT      All bands
# 92       31              3               STFT      All bands
# 93       32              3               STFT      All bands
# 94       32              3               STFT      All bands
# 95       32              3               STFT      All bands
#
#    Channel selection Classification algorithm  Accuracy  Happy precision  \
# 0                  -            Random Forest  0.966797         0.954918
# 1                  -                      SVM  0.960938         0.969957
# ...

# %%
'''
rf_acc_arr_3 = []
svm_acc_arr_3 = []
knn_acc_arr_3 = []

rf_happy_arr_3 = []
svm_happy_arr_3 = []
knn_happy_arr_3 = []

rf_sad_arr_3 = []
svm_sad_arr_3 = []
knn_sad_arr_3 = []

exp3_acc = exp3_df['Accuracy']
exp3_happy = exp3_df['Happy f1-score']
exp3_sad = exp3_df['Sad f1-score']

print(len(exp3_acc))
for i in range (0,len(exp3_acc)):
    if (i%3 == 0):
        rf_acc_arr_3.append(exp3_acc[i])
        rf_happy_arr_3.append(exp3_happy[i])
        rf_sad_arr_3.append(exp3_sad[i])
    if (i%3 == 1):
        svm_acc_arr_3.append(exp3_acc[i])
        svm_happy_arr_3.append(exp3_happy[i])
        svm_sad_arr_3.append(exp3_sad[i])
    if (i%3 == 2):
        knn_acc_arr_3.append(exp3_acc[i])
        knn_happy_arr_3.append(exp3_happy[i])
        knn_sad_arr_3.append(exp3_sad[i])

print(rf_acc_arr_3)
print(svm_acc_arr_3)
print(knn_acc_arr_3)
'''
# Out:
# "\nrf_acc_arr_3 = []\nsvm_acc_arr_3 = []\nknn_acc_arr_3 = []\n\nrf_happy_arr_3 = []\nsvm_happy_arr_3 = []\nknn_happy_arr_3 = []\n\nrf_sad_arr_3 = []\nsvm_sad_arr_3 = []\nknn_sad_arr_3 = []\n\nexp3_acc = exp3_df['Accuracy']\nexp3_happy = exp3_df['Happy f1-score']\nexp3_sad = exp3_df['Sad f1-score']\n\nprint(len(exp3_acc))\nfor i in range (0,len(exp3_acc)):\n    if (i%3 == 0):\n        rf_acc_arr_3.append(exp3_acc[i])\n        rf_happy_arr_3.append(exp3_happy[i])\n        rf_sad_arr_3.append(exp3_sad[i])\n    if (i%3 == 1):\n        svm_acc_arr_3.append(exp3_acc[i])\n        svm_happy_arr_3.append(exp3_happy[i])\n        svm_sad_arr_3.append(exp3_sad[i])\n    if (i%3 == 2):\n        knn_acc_arr_3.append(exp3_acc[i])\n        knn_happy_arr_3.append(exp3_happy[i])\n        knn_sad_arr_3.append(exp3_sad[i])\n\nprint(rf_acc_arr_3)\nprint(svm_acc_arr_3)\nprint(knn_acc_arr_3)\n"

# %%
'''
rf_mean_3 = statistics.mean(rf_acc_arr_3)
print("RF mean: ", rf_mean_3)
svm_mean_3 = statistics.mean(svm_acc_arr_3)
print("SVM mean: ", svm_mean_3)
knn_mean_3 = statistics.mean(knn_acc_arr_3)
print("kNN mean: ", knn_mean_3)

rf_acc_means.append(rf_mean_3)
svm_acc_means.append(svm_mean_3)
knn_acc_means.append(knn_mean_3)

rf_std = np.std(rf_acc_arr_3)
svm_std = np.std(svm_acc_arr_3)
knn_std = np.std(knn_acc_arr_3)

rf_acc_std.append(rf_std)
svm_acc_std.append(svm_std)
knn_acc_std.append(knn_std)

rf_happy_mean3 = statistics.mean(rf_happy_arr_3)
print("RF mean: ", rf_happy_mean3)
svm_happy_mean3 = statistics.mean(svm_happy_arr_3)
print("SVM mean: ", svm_happy_mean3)
knn_happy_mean3 = statistics.mean(knn_happy_arr_3)
print("kNN mean: ", knn_happy_mean3)

rf_happy_means.append(rf_happy_mean3)
svm_happy_means.append(svm_happy_mean3)
knn_happy_means.append(knn_happy_mean3)

rf_sad_mean3 = statistics.mean(rf_sad_arr_3)
print("RF mean: ", rf_sad_mean3)
svm_sad_mean3 = statistics.mean(svm_sad_arr_3)
print("SVM mean: ", svm_sad_mean3)
knn_sad_mean3 = statistics.mean(knn_sad_arr_3)
print("kNN mean: ", knn_sad_mean3)

rf_sad_means.append(rf_sad_mean3)
svm_sad_means.append(svm_sad_mean3)
knn_sad_means.append(knn_sad_mean3)
'''
# Out:
# '\nrf_mean_3 = statistics.mean(rf_acc_arr_3)\nprint("RF mean: ", rf_mean_3)\nsvm_mean_3 = statistics.mean(svm_acc_arr_3)\nprint("SVM mean: ", svm_mean_3)\nknn_mean_3 = statistics.mean(knn_acc_arr_3)\nprint("kNN mean: ", knn_mean_3)\n\nrf_acc_means.append(rf_mean_3)\nsvm_acc_means.append(svm_mean_3)\nknn_acc_means.append(knn_mean_3)\n\nrf_std = np.std(rf_acc_arr_3)\nsvm_std = np.std(svm_acc_arr_3)\nknn_std = np.std(knn_acc_arr_3)\n\nrf_acc_std.append(rf_std)\nsvm_acc_std.append(svm_std)\nknn_acc_std.append(knn_std)\n\nrf_happy_mean3 = statistics.mean(rf_happy_arr_3)\nprint("RF mean: ", rf_happy_mean3)\nsvm_happy_mean3 = statistics.mean(svm_happy_arr_3)\nprint("SVM mean: ", svm_happy_mean3)\nknn_happy_mean3 = statistics.mean(knn_happy_arr_3)\nprint("kNN mean: ", knn_happy_mean3)\n\nrf_happy_means.append(rf_happy_mean3)\nsvm_happy_means.append(svm_happy_mean3)\nknn_happy_means.append(knn_happy_mean3)\n\nrf_sad_mean3 = statistics.mean(rf_sad_arr_3)\nprint("RF mean: ", rf_sad_mean3)\nsvm_
# ...

# %%
'''
rf_acc_arr_3 = []
svm_acc_arr_3 = []
knn_acc_arr_3 = []

rf_happy_arr_3 = []
svm_happy_arr_3 = []
knn_happy_arr_3 = []

rf_sad_arr_3 = []
svm_sad_arr_3 = []
knn_sad_arr_3 = []

exp3_acc = exp3_1_df['Accuracy']
exp3_happy = exp3_1_df['Happy f1-score']
exp3_sad = exp3_1_df['Sad f1-score']

print(len(exp3_acc))
for i in range (0,len(exp3_acc)):
    if (i%3 == 0):
        rf_acc_arr_3.append(exp3_acc[i])
        rf_happy_arr_3.append(exp3_happy[i])
        rf_sad_arr_3.append(exp3_sad[i])
    if (i%3 == 1):
        svm_acc_arr_3.append(exp3_acc[i])
        svm_happy_arr_3.append(exp3_happy[i])
        svm_sad_arr_3.append(exp3_sad[i])
    if (i%3 == 2):
        knn_acc_arr_3.append(exp3_acc[i])
        knn_happy_arr_3.append(exp3_happy[i])
        knn_sad_arr_3.append(exp3_sad[i])

print(rf_acc_arr_3)
print(svm_acc_arr_3)
print(knn_acc_arr_3)

rf_mean_3 = statistics.mean(rf_acc_arr_3)
print("RF mean: ", rf_mean_3)
svm_mean_3 = statistics.mean(svm_acc_arr_3)
print("SVM mean: ", svm_mean_3)
knn_mean_3 = statistics.mean(knn_acc_arr_3)
print("kNN mean: ", knn_mean_3)

rf_acc_means.append(rf_mean_3)
svm_acc_means.append(svm_mean_3)
knn_acc_means.append(knn_mean_3)

rf_std = np.std(rf_acc_arr_3)
svm_std = np.std(svm_acc_arr_3)
knn_std = np.std(knn_acc_arr_3)

rf_acc_std.append(rf_std)
svm_acc_std.append(svm_std)
knn_acc_std.append(knn_std)

rf_happy_mean3 = statistics.mean(rf_happy_arr_3)
print("RF mean: ", rf_happy_mean3)
svm_happy_mean3 = statistics.mean(svm_happy_arr_3)
print("SVM mean: ", svm_happy_mean3)
knn_happy_mean3 = statistics.mean(knn_happy_arr_3)
print("kNN mean: ", knn_happy_mean3)

rf_happy_means.append(rf_happy_mean3)
svm_happy_means.append(svm_happy_mean3)
knn_happy_means.append(knn_happy_mean3)

rf_sad_mean3 = statistics.mean(rf_sad_arr_3)
print("RF mean: ", rf_sad_mean3)
svm_sad_mean3 = statistics.mean(svm_sad_arr_3)
print("SVM mean: ", svm_sad_mean3)
knn_sad_mean3 = statistics.mean(knn_sad_arr_3)
print("kNN mean: ", knn_sad_mean3)

rf_sad_means.append(rf_sad_mean3)
svm_sad_means.append(svm_sad_mean3)
knn_sad_means.append(knn_sad_mean3)
'''
# Out:
# '\nrf_acc_arr_3 = []\nsvm_acc_arr_3 = []\nknn_acc_arr_3 = []\n\nrf_happy_arr_3 = []\nsvm_happy_arr_3 = []\nknn_happy_arr_3 = []\n\nrf_sad_arr_3 = []\nsvm_sad_arr_3 = []\nknn_sad_arr_3 = []\n\nexp3_acc = exp3_1_df[\'Accuracy\']\nexp3_happy = exp3_1_df[\'Happy f1-score\']\nexp3_sad = exp3_1_df[\'Sad f1-score\']\n\nprint(len(exp3_acc))\nfor i in range (0,len(exp3_acc)):\n    if (i%3 == 0):\n        rf_acc_arr_3.append(exp3_acc[i])\n        rf_happy_arr_3.append(exp3_happy[i])\n        rf_sad_arr_3.append(exp3_sad[i])\n    if (i%3 == 1):\n        svm_acc_arr_3.append(exp3_acc[i])\n        svm_happy_arr_3.append(exp3_happy[i])\n        svm_sad_arr_3.append(exp3_sad[i])\n    if (i%3 == 2):\n        knn_acc_arr_3.append(exp3_acc[i])\n        knn_happy_arr_3.append(exp3_happy[i])\n        knn_sad_arr_3.append(exp3_sad[i])\n\nprint(rf_acc_arr_3)\nprint(svm_acc_arr_3)\nprint(knn_acc_arr_3)\n\nrf_mean_3 = statistics.mean(rf_acc_arr_3)\nprint("RF mean: ", rf_mean_3)\nsvm_mean_3 = statistics.mean
# ...

# %%
rf_acc_arr_3 = []
svm_acc_arr_3 = []
knn_acc_arr_3 = []

rf_happy_arr_3 = []
svm_happy_arr_3 = []
knn_happy_arr_3 = []

rf_sad_arr_3 = []
svm_sad_arr_3 = []
knn_sad_arr_3 = []

exp3_acc = exp3_2_df['Accuracy']
exp3_happy = exp3_2_df['Happy f1-score']
exp3_sad = exp3_2_df['Sad f1-score']

print(len(exp3_acc))
for i in range (0,len(exp3_acc)):
    if (i%3 == 0):
        rf_acc_arr_3.append(exp3_acc[i])
        rf_happy_arr_3.append(exp3_happy[i])
        rf_sad_arr_3.append(exp3_sad[i])
    if (i%3 == 1):
        svm_acc_arr_3.append(exp3_acc[i])
        svm_happy_arr_3.append(exp3_happy[i])
        svm_sad_arr_3.append(exp3_sad[i])
    if (i%3 == 2):
        knn_acc_arr_3.append(exp3_acc[i])
        knn_happy_arr_3.append(exp3_happy[i])
        knn_sad_arr_3.append(exp3_sad[i])

print(rf_acc_arr_3)
print(svm_acc_arr_3)
print(knn_acc_arr_3)

rf_mean_3 = statistics.mean(rf_acc_arr_3)
print("RF mean: ", rf_mean_3)
svm_mean_3 = statistics.mean(svm_acc_arr_3)
print("SVM mean: ", svm_mean_3)
knn_mean_3 = statistics.mean(knn_acc_arr_3)
print("kNN mean: ", knn_mean_3)

rf_acc_means.append(rf_mean_3)
svm_acc_means.append(svm_mean_3)
knn_acc_means.append(knn_mean_3)

rf_std = np.std(rf_acc_arr_3)
svm_std = np.std(svm_acc_arr_3)
knn_std = np.std(knn_acc_arr_3)

rf_acc_std.append(rf_std)
svm_acc_std.append(svm_std)
knn_acc_std.append(knn_std)

rf_happy_mean3 = statistics.mean(rf_happy_arr_3)
print("RF mean: ", rf_happy_mean3)
svm_happy_mean3 = statistics.mean(svm_happy_arr_3)
print("SVM mean: ", svm_happy_mean3)
knn_happy_mean3 = statistics.mean(knn_happy_arr_3)
print("kNN mean: ", knn_happy_mean3)

rf_happy_means.append(rf_happy_mean3)
svm_happy_means.append(svm_happy_mean3)
knn_happy_means.append(knn_happy_mean3)

rf_sad_mean3 = statistics.mean(rf_sad_arr_3)
print("RF mean: ", rf_sad_mean3)
svm_sad_mean3 = statistics.mean(svm_sad_arr_3)
print("SVM mean: ", svm_sad_mean3)
knn_sad_mean3 = statistics.mean(knn_sad_arr_3)
print("kNN mean: ", knn_sad_mean3)

rf_sad_means.append(rf_sad_mean3)
svm_sad_means.append(svm_sad_mean3)
knn_sad_means.append(knn_sad_mean3)

rf_happy_std3 = np.std(rf_happy_arr_3)
print("RF std: ", rf_happy_std3)
svm_happy_std3 = np.std(svm_happy_arr_3)
print("SVM std: ", svm_happy_std3)
knn_happy_std3 = np.std(knn_happy_arr_3)
print("kNN std: ", knn_happy_std3)

rf_happy_stds.append(rf_happy_std3)
svm_happy_stds.append(svm_happy_std3)
knn_happy_stds.append(knn_happy_std3)

rf_sad_std3 = np.std(rf_sad_arr_3)
print("RF std: ", rf_sad_std3)
svm_sad_std3 = np.std(svm_sad_arr_3)
print("SVM std: ", svm_sad_std3)
knn_sad_std3 = np.std(knn_sad_arr_3)
print("kNN std: ", knn_sad_std3)

rf_sad_stds.append(rf_sad_std3)
svm_sad_stds.append(svm_sad_std3)
knn_sad_stds.append(knn_sad_std3)
# Out:
# 96
# [0.966796875, 0.9609375, 0.9375, 0.939453125, 0.923828125, 0.953125, 0.96875, 0.943359375, 0.92578125, 0.96484375, 0.96484375, 0.96875, 0.95703125, 0.97265625, 0.97265625, 0.927734375, 0.96484375, 0.95703125, 0.96875, 0.982421875, 0.955078125, 0.94921875, 0.978515625, 0.96484375, 0.94140625, 0.970703125, 0.92578125, 0.93359375, 0.98046875, 0.947265625, 0.953125, 0.9609375]
# [0.966796875, 0.9609375, 0.9375, 0.939453125, 0.923828125, 0.9375, 0.96875, 0.943359375, 0.92578125, 0.94921875, 0.96484375, 0.96875, 0.966796875, 0.97265625, 0.97265625, 0.927734375, 0.96484375, 0.95703125, 0.96875, 0.970703125, 0.955078125, 0.953125, 0.97265625, 0.96484375, 0.94140625, 0.970703125, 0.92578125, 0.9453125, 0.98046875, 0.947265625, 0.9375, 0.9609375]
# ...

# %%
'''
rf_acc_arr_3 = []
svm_acc_arr_3 = []
knn_acc_arr_3 = []

rf_happy_arr_3 = []
svm_happy_arr_3 = []
knn_happy_arr_3 = []

rf_sad_arr_3 = []
svm_sad_arr_3 = []
knn_sad_arr_3 = []

exp3_acc = exp3_3_df['Accuracy']
exp3_happy = exp3_3_df['Happy f1-score']
exp3_sad = exp3_3_df['Sad f1-score']

print(len(exp3_acc))
for i in range (0,len(exp3_acc)):
    if (i%3 == 0):
        rf_acc_arr_3.append(exp3_acc[i])
        rf_happy_arr_3.append(exp3_happy[i])
        rf_sad_arr_3.append(exp3_sad[i])
    if (i%3 == 1):
        svm_acc_arr_3.append(exp3_acc[i])
        svm_happy_arr_3.append(exp3_happy[i])
        svm_sad_arr_3.append(exp3_sad[i])
    if (i%3 == 2):
        knn_acc_arr_3.append(exp3_acc[i])
        knn_happy_arr_3.append(exp3_happy[i])
        knn_sad_arr_3.append(exp3_sad[i])

print(rf_acc_arr_3)
print(svm_acc_arr_3)
print(knn_acc_arr_3)

rf_mean_3 = statistics.mean(rf_acc_arr_3)
print("RF mean: ", rf_mean_3)
svm_mean_3 = statistics.mean(svm_acc_arr_3)
print("SVM mean: ", svm_mean_3)
knn_mean_3 = statistics.mean(knn_acc_arr_3)
print("kNN mean: ", knn_mean_3)

rf_acc_means.append(rf_mean_3)
svm_acc_means.append(svm_mean_3)
knn_acc_means.append(knn_mean_3)

rf_std = np.std(rf_acc_arr_3)
svm_std = np.std(svm_acc_arr_3)
knn_std = np.std(knn_acc_arr_3)

rf_acc_std.append(rf_std)
svm_acc_std.append(svm_std)
knn_acc_std.append(knn_std)

rf_happy_mean3 = statistics.mean(rf_happy_arr_3)
print("RF mean: ", rf_happy_mean3)
svm_happy_mean3 = statistics.mean(svm_happy_arr_3)
print("SVM mean: ", svm_happy_mean3)
knn_happy_mean3 = statistics.mean(knn_happy_arr_3)
print("kNN mean: ", knn_happy_mean3)

rf_happy_means.append(rf_happy_mean3)
svm_happy_means.append(svm_happy_mean3)
knn_happy_means.append(knn_happy_mean3)

rf_sad_mean3 = statistics.mean(rf_sad_arr_3)
print("RF mean: ", rf_sad_mean3)
svm_sad_mean3 = statistics.mean(svm_sad_arr_3)
print("SVM mean: ", svm_sad_mean3)
knn_sad_mean3 = statistics.mean(knn_sad_arr_3)
print("kNN mean: ", knn_sad_mean3)

rf_sad_means.append(rf_sad_mean3)
svm_sad_means.append(svm_sad_mean3)
knn_sad_means.append(knn_sad_mean3)
'''
# Out:
# '\nrf_acc_arr_3 = []\nsvm_acc_arr_3 = []\nknn_acc_arr_3 = []\n\nrf_happy_arr_3 = []\nsvm_happy_arr_3 = []\nknn_happy_arr_3 = []\n\nrf_sad_arr_3 = []\nsvm_sad_arr_3 = []\nknn_sad_arr_3 = []\n\nexp3_acc = exp3_3_df[\'Accuracy\']\nexp3_happy = exp3_3_df[\'Happy f1-score\']\nexp3_sad = exp3_3_df[\'Sad f1-score\']\n\nprint(len(exp3_acc))\nfor i in range (0,len(exp3_acc)):\n    if (i%3 == 0):\n        rf_acc_arr_3.append(exp3_acc[i])\n        rf_happy_arr_3.append(exp3_happy[i])\n        rf_sad_arr_3.append(exp3_sad[i])\n    if (i%3 == 1):\n        svm_acc_arr_3.append(exp3_acc[i])\n        svm_happy_arr_3.append(exp3_happy[i])\n        svm_sad_arr_3.append(exp3_sad[i])\n    if (i%3 == 2):\n        knn_acc_arr_3.append(exp3_acc[i])\n        knn_happy_arr_3.append(exp3_happy[i])\n        knn_sad_arr_3.append(exp3_sad[i])\n\nprint(rf_acc_arr_3)\nprint(svm_acc_arr_3)\nprint(knn_acc_arr_3)\n\nrf_mean_3 = statistics.mean(rf_acc_arr_3)\nprint("RF mean: ", rf_mean_3)\nsvm_mean_3 = statistics.mean
# ...

# %%
exp4_df
# Out:
#      Subject  Experiment ID Feature extraction Band selection  \
# 0          1              4               STFT      All bands
# 1          1              4               STFT      All bands
# 2          1              4               STFT      All bands
# 3          1              4               STFT      All bands
# 4          2              4               STFT      All bands
# ..       ...            ...                ...            ...
# 123       31              4               STFT      All bands
# 124       32              4               STFT      All bands
# 125       32              4               STFT      All bands
# 126       32              4               STFT      All bands
# 127       32              4               STFT      All bands
#
#     Channel selection Classification algorithm  Accuracy  Happy precision  \
# 0          Literature            Random Forest  0.910156         0.893878
# ...

# %%
'''
rf_lit_acc_arr = []
svm_lit_acc_arr = []
rf_own_acc_arr = []
svm_own_acc_arr = []

rf_lit_happy_arr = []
svm_lit_happy_arr = []
rf_own_happy_arr = []
svm_own_happy_arr = []

rf_lit_sad_arr = []
svm_lit_sad_arr = []
rf_own_sad_arr = []
svm_own_sad_arr = []

exp4_acc = exp4_df['Accuracy']
exp4_happy = exp4_df['Happy f1-score']
exp4_sad = exp4_df['Sad f1-score']

print(len(exp4_acc))
for i in range (0,len(exp4_acc)):
    if (i%4 == 0):
        rf_lit_acc_arr.append(exp4_acc[i])
        rf_lit_happy_arr.append(exp4_happy[i])
        rf_lit_sad_arr.append(exp4_sad[i])
    if (i%4 == 1):
        svm_lit_acc_arr.append(exp4_acc[i])
        svm_lit_happy_arr.append(exp4_happy[i])
        svm_lit_sad_arr.append(exp4_sad[i])
    if (i%4 == 2):
        rf_own_acc_arr.append(exp4_acc[i])
        rf_own_happy_arr.append(exp4_happy[i])
        rf_own_sad_arr.append(exp4_sad[i])
    if (i%4 == 3):
        svm_own_acc_arr.append(exp4_acc[i])
        svm_own_happy_arr.append(exp4_happy[i])
        svm_own_sad_arr.append(exp4_sad[i])


print(rf_lit_acc_arr)
print(svm_lit_acc_arr)
print(rf_own_acc_arr)
print(svm_own_acc_arr)
'''
# Out:
# "\nrf_lit_acc_arr = []\nsvm_lit_acc_arr = []\nrf_own_acc_arr = []\nsvm_own_acc_arr = []\n\nrf_lit_happy_arr = []\nsvm_lit_happy_arr = []\nrf_own_happy_arr = []\nsvm_own_happy_arr = []\n\nrf_lit_sad_arr = []\nsvm_lit_sad_arr = []\nrf_own_sad_arr = []\nsvm_own_sad_arr = []\n\nexp4_acc = exp4_df['Accuracy']\nexp4_happy = exp4_df['Happy f1-score']\nexp4_sad = exp4_df['Sad f1-score']\n\nprint(len(exp4_acc))\nfor i in range (0,len(exp4_acc)):\n    if (i%4 == 0):\n        rf_lit_acc_arr.append(exp4_acc[i])\n        rf_lit_happy_arr.append(exp4_happy[i])\n        rf_lit_sad_arr.append(exp4_sad[i])\n    if (i%4 == 1):\n        svm_lit_acc_arr.append(exp4_acc[i])\n        svm_lit_happy_arr.append(exp4_happy[i])\n        svm_lit_sad_arr.append(exp4_sad[i])\n    if (i%4 == 2):\n        rf_own_acc_arr.append(exp4_acc[i])\n        rf_own_happy_arr.append(exp4_happy[i])\n        rf_own_sad_arr.append(exp4_sad[i])\n    if (i%4 == 3):\n        svm_own_acc_arr.append(exp4_acc[i])\n        svm_own_happ
# ...

# %%
'''
rf_lit_mean = statistics.mean(rf_lit_acc_arr)
print("RF literature mean: ", rf_lit_mean)
svm_lit_mean = statistics.mean(svm_lit_acc_arr)
print("SVM literature mean: ", svm_lit_mean)
rf_own_mean = statistics.mean(rf_own_acc_arr)
print("RF own mean: ", rf_own_mean)
svm_own_mean = statistics.mean(svm_own_acc_arr)
print("SVM own mean: ", svm_own_mean)

rf_acc_means.append(rf_own_mean)
rf_acc_means.append(rf_lit_mean)
svm_acc_means.append(svm_own_mean)
svm_acc_means.append(svm_lit_mean)
knn_acc_means.append(None)
knn_acc_means.append(None)

rf_own_std = np.std(rf_own_acc_arr)
svm_own_std = np.std(svm_own_acc_arr)
rf_lit_std = np.std(rf_lit_acc_arr)
svm_lit_std = np.std(svm_lit_acc_arr)

rf_acc_std.append(rf_own_std)
rf_acc_std.append(rf_lit_std)
svm_acc_std.append(svm_own_std)
svm_acc_std.append(svm_lit_std)
knn_acc_std.append(None)
knn_acc_std.append(None)

rf_lit_happy_mean = statistics.mean(rf_lit_happy_arr)
print("RF literature mean: ", rf_lit_happy_mean)
svm_lit_happy_mean = statistics.mean(svm_lit_happy_arr)
print("SVM literature mean: ", svm_lit_happy_mean)
rf_own_happy_mean = statistics.mean(rf_own_happy_arr)
print("RF own mean: ", rf_own_happy_mean)
svm_own_happy_mean = statistics.mean(svm_own_happy_arr)
print("SVM own mean: ", svm_own_happy_mean)

rf_happy_means.append(rf_own_happy_mean)
rf_happy_means.append(rf_lit_happy_mean)

svm_happy_means.append(svm_own_happy_mean)
svm_happy_means.append(svm_lit_happy_mean)

knn_happy_means.append(None)
knn_happy_means.append(None)

rf_lit_sad_mean = statistics.mean(rf_lit_sad_arr)
print("RF literature mean: ", rf_lit_sad_mean)
svm_lit_sad_mean = statistics.mean(svm_lit_sad_arr)
print("SVM literature mean: ", svm_lit_sad_mean)
rf_own_sad_mean = statistics.mean(rf_own_sad_arr)
print("RF own mean: ", rf_own_sad_mean)
svm_own_sad_mean = statistics.mean(svm_own_sad_arr)
print("SVM own mean: ", svm_own_sad_mean)

rf_sad_means.append(rf_own_sad_mean)
rf_sad_means.append(rf_lit_sad_mean)

svm_sad_means.append(svm_own_sad_mean)
svm_sad_means.append(svm_lit_sad_mean)

knn_sad_means.append(None)
knn_sad_means.append(None)
'''
# Out:
# '\nrf_lit_mean = statistics.mean(rf_lit_acc_arr)\nprint("RF literature mean: ", rf_lit_mean)\nsvm_lit_mean = statistics.mean(svm_lit_acc_arr)\nprint("SVM literature mean: ", svm_lit_mean)\nrf_own_mean = statistics.mean(rf_own_acc_arr)\nprint("RF own mean: ", rf_own_mean)\nsvm_own_mean = statistics.mean(svm_own_acc_arr)\nprint("SVM own mean: ", svm_own_mean)\n\nrf_acc_means.append(rf_own_mean)\nrf_acc_means.append(rf_lit_mean)\nsvm_acc_means.append(svm_own_mean)\nsvm_acc_means.append(svm_lit_mean)\nknn_acc_means.append(None)\nknn_acc_means.append(None)\n\nrf_own_std = np.std(rf_own_acc_arr)\nsvm_own_std = np.std(svm_own_acc_arr)\nrf_lit_std = np.std(rf_lit_acc_arr)\nsvm_lit_std = np.std(svm_lit_acc_arr)\n\nrf_acc_std.append(rf_own_std)\nrf_acc_std.append(rf_lit_std)\nsvm_acc_std.append(svm_own_std)\nsvm_acc_std.append(svm_lit_std)\nknn_acc_std.append(None)\nknn_acc_std.append(None)\n\nrf_lit_happy_mean = statistics.mean(rf_lit_happy_arr)\nprint("RF literature mean: ", rf_lit_happy_mea
# ...

# %%
rf_lit_acc_arr = []
svm_lit_acc_arr = []
knn_lit_acc_arr = []
rf_own_acc_arr = []
svm_own_acc_arr = []
knn_own_acc_arr = []

rf_lit_happy_arr = []
svm_lit_happy_arr = []
knn_lit_happy_arr = []
rf_own_happy_arr = []
svm_own_happy_arr = []
knn_own_happy_arr = []

rf_lit_sad_arr = []
svm_lit_sad_arr = []
knn_lit_sad_arr = []
rf_own_sad_arr = []
svm_own_sad_arr = []
knn_own_sad_arr = []

exp4_acc = exp4_1_df['Accuracy']
exp4_happy = exp4_1_df['Happy f1-score']
exp4_sad = exp4_1_df['Sad f1-score']

print(len(exp4_acc))
for i in range (0,len(exp4_acc)):
    if (i%6 == 0):
        rf_lit_acc_arr.append(exp4_acc[i])
        rf_lit_happy_arr.append(exp4_happy[i])
        rf_lit_sad_arr.append(exp4_sad[i])
    if (i%6 == 1):
        svm_lit_acc_arr.append(exp4_acc[i])
        svm_lit_happy_arr.append(exp4_happy[i])
        svm_lit_sad_arr.append(exp4_sad[i])
    if (i%6 == 2):
        knn_lit_acc_arr.append(exp4_acc[i])
        knn_lit_happy_arr.append(exp4_happy[i])
        knn_lit_sad_arr.append(exp4_sad[i])
    if (i%6 == 3):
        rf_own_acc_arr.append(exp4_acc[i])
        rf_own_happy_arr.append(exp4_happy[i])
        rf_own_sad_arr.append(exp4_sad[i])
    if (i%6 == 4):
        svm_own_acc_arr.append(exp4_acc[i])
        svm_own_happy_arr.append(exp4_happy[i])
        svm_own_sad_arr.append(exp4_sad[i])
    if (i%6 == 5):
        knn_own_acc_arr.append(exp4_acc[i])
        knn_own_happy_arr.append(exp4_happy[i])
        knn_own_sad_arr.append(exp4_sad[i])


print(rf_lit_acc_arr)
print(svm_lit_acc_arr)
print(knn_lit_acc_arr)
print(rf_own_acc_arr)
print(svm_own_acc_arr)
print(knn_own_acc_arr)

rf_lit_mean = statistics.mean(rf_lit_acc_arr)
print("RF literature mean: ", rf_lit_mean)
svm_lit_mean = statistics.mean(svm_lit_acc_arr)
print("SVM literature mean: ", svm_lit_mean)
knn_lit_mean = statistics.mean(knn_lit_acc_arr)
print("kNN literature mean: ", knn_lit_mean)
rf_own_mean = statistics.mean(rf_own_acc_arr)
print("RF own mean: ", rf_own_mean)
svm_own_mean = statistics.mean(svm_own_acc_arr)
print("SVM own mean: ", svm_own_mean)
knn_own_mean = statistics.mean(knn_own_acc_arr)
print("kNN own mean: ", knn_own_mean)

rf_acc_means.append(rf_own_mean)
rf_acc_means.append(rf_lit_mean)
svm_acc_means.append(svm_own_mean)
svm_acc_means.append(svm_lit_mean)
knn_acc_means.append(knn_own_mean)
knn_acc_means.append(knn_lit_mean)

rf_own_std = np.std(rf_own_acc_arr)
svm_own_std = np.std(svm_own_acc_arr)
knn_own_std = np.std(knn_own_acc_arr)
rf_lit_std = np.std(rf_lit_acc_arr)
svm_lit_std = np.std(svm_lit_acc_arr)
knn_lit_std = np.std(knn_lit_acc_arr)

rf_acc_std.append(rf_own_std)
rf_acc_std.append(rf_lit_std)
svm_acc_std.append(svm_own_std)
svm_acc_std.append(svm_lit_std)
knn_acc_std.append(knn_own_std)
knn_acc_std.append(knn_lit_std)

rf_lit_happy_mean = statistics.mean(rf_lit_happy_arr)
print("RF literature mean: ", rf_lit_happy_mean)
svm_lit_happy_mean = statistics.mean(svm_lit_happy_arr)
print("SVM literature mean: ", svm_lit_happy_mean)
knn_lit_happy_mean = statistics.mean(knn_lit_happy_arr)
print("kNN literature mean: ", knn_lit_happy_mean)
rf_own_happy_mean = statistics.mean(rf_own_happy_arr)
print("RF own mean: ", rf_own_happy_mean)
svm_own_happy_mean = statistics.mean(svm_own_happy_arr)
print("SVM own mean: ", svm_own_happy_mean)
knn_own_happy_mean = statistics.mean(knn_own_happy_arr)
print("kNN own mean: ", knn_own_happy_mean)

rf_happy_means.append(rf_own_happy_mean)
rf_happy_means.append(rf_lit_happy_mean)

svm_happy_means.append(svm_own_happy_mean)
svm_happy_means.append(svm_lit_happy_mean)

knn_happy_means.append(knn_own_mean)
knn_happy_means.append(knn_lit_mean)

rf_lit_sad_mean = statistics.mean(rf_lit_sad_arr)
print("RF literature mean: ", rf_lit_sad_mean)
svm_lit_sad_mean = statistics.mean(svm_lit_sad_arr)
print("SVM literature mean: ", svm_lit_sad_mean)
knn_lit_sad_mean = statistics.mean(knn_lit_sad_arr)
print("kNN literature mean: ", knn_lit_sad_mean)
rf_own_sad_mean = statistics.mean(rf_own_sad_arr)
print("RF own mean: ", rf_own_sad_mean)
svm_own_sad_mean = statistics.mean(svm_own_sad_arr)
print("SVM own mean: ", svm_own_sad_mean)
knn_own_sad_mean = statistics.mean(knn_own_sad_arr)
print("kNN own mean: ", knn_own_sad_mean)

rf_sad_means.append(rf_own_sad_mean)
rf_sad_means.append(rf_lit_sad_mean)

svm_sad_means.append(svm_own_sad_mean)
svm_sad_means.append(svm_lit_sad_mean)

knn_sad_means.append(knn_own_mean)
knn_sad_means.append(knn_lit_mean)

rf_lit_happy_std = np.std(rf_lit_happy_arr)
print("RF literature std: ", rf_lit_happy_std)
svm_lit_happy_std = np.std(svm_lit_happy_arr)
print("SVM literature std: ", svm_lit_happy_std)
knn_lit_happy_std = np.std(knn_lit_happy_arr)
print("kNN literature std: ", knn_lit_happy_std)
rf_own_happy_std = np.std(rf_own_happy_arr)
print("RF own std: ", rf_own_happy_std)
svm_own_happy_std = np.std(svm_own_happy_arr)
print("SVM own std: ", svm_own_happy_std)
knn_own_happy_std = np.std(knn_own_happy_arr)
print("kNN own std: ", knn_own_happy_std)

rf_happy_stds.append(rf_own_happy_std)
rf_happy_stds.append(rf_lit_happy_std)

svm_happy_stds.append(svm_own_happy_std)
svm_happy_stds.append(svm_lit_happy_std)

knn_happy_stds.append(knn_own_std)
knn_happy_stds.append(knn_lit_std)

rf_lit_sad_std = np.std(rf_lit_sad_arr)
print("RF literature std: ", rf_lit_sad_std)
svm_lit_sad_std = np.std(svm_lit_sad_arr)
print("SVM literature std: ", svm_lit_sad_std)
knn_lit_sad_std = np.std(knn_lit_sad_arr)
print("kNN literature std: ", knn_lit_sad_std)
rf_own_sad_std = np.std(rf_own_sad_arr)
print("RF own std: ", rf_own_sad_std)
svm_own_sad_std = np.std(svm_own_sad_arr)
print("SVM own std: ", svm_own_sad_std)
knn_own_sad_std = np.std(knn_own_sad_arr)
print("kNN own std: ", knn_own_sad_std)

rf_sad_stds.append(rf_own_sad_std)
rf_sad_stds.append(rf_lit_sad_std)

svm_sad_stds.append(svm_own_sad_std)
svm_sad_stds.append(svm_lit_sad_std)

knn_sad_stds.append(knn_own_std)
knn_sad_stds.append(knn_lit_std)
# Out:
# 132
# [0.96875, 0.951171875, 0.966796875, 0.94921875, 0.97265625, 0.97265625, 0.927734375, 0.94921875, 0.95703125, 0.96875, 0.982421875, 0.955078125, 0.978515625, 0.96484375, 0.94140625, 0.970703125, 0.94140625, 0.93359375, 0.98046875, 0.931640625, 0.953125, 0.9609375]
# [0.91015625, 0.896484375, 0.966796875, 0.89453125, 0.888671875, 0.90234375, 0.912109375, 0.94921875, 0.955078125, 0.87890625, 0.982421875, 0.94921875, 0.978515625, 0.818359375, 0.822265625, 0.880859375, 0.919921875, 0.93359375, 0.98046875, 0.89453125, 0.94140625, 0.9140625]
# [0.9609375, 0.947265625, 0.95703125, 0.9609375, 0.97265625, 0.97265625, 0.921875, 0.94921875, 0.95703125, 0.96875, 0.970703125, 0.955078125, 0.95703125, 0.947265625, 0.9296875, 0.970703125, 0.939453125, 0.9453125, 0.96875, 0.9296875, 0.953125, 0.958984375]
# ...

# %%
print(len(rf_acc_means))
print(len(svm_acc_means))
print(len(knn_acc_means))

print(len(rf_happy_means))
print(len(svm_happy_means))
print(len(knn_happy_means))

print(len(rf_sad_means))
print(len(svm_sad_means))
print(len(knn_sad_means))
# Out:
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9

# %%
data = {'RF': rf_acc_means, 'RF std': rf_acc_std, 'SVM': svm_acc_means, 'SVM std': svm_acc_std, 'kNN': knn_acc_means, 'kNN std': knn_acc_std, 'RF Happy': rf_happy_means, 'RF Happy std':rf_happy_stds, 'SVM Happy': svm_happy_means, 'SVM Happy std': svm_happy_stds, 'kNN Happy': knn_happy_means, 'kNN Happy std':knn_happy_stds, 'RF Sad': rf_sad_means, 'RF Sad std':rf_sad_stds, 'SVM Sad': svm_sad_means, 'SVM Sad std':svm_sad_stds, 'kNN Sad': knn_sad_means, 'kNN Sad std':knn_sad_stds}
df = pd.DataFrame(data)
df.index = ['Experiment 1', 'Experiment 2_1 Delta', 'Experiment 2_1 Theta', 'Experiment 2_1 Alpha', 'Experiment 2_1 Beta', 'Experiment 2_1 Gamma', 'Experiment 3_2 (All bands)', 'Experiment 4_1 Own', 'Experiment 4_1 Literature']
df2 = np.round(df*100, decimals= 2)
df2
# Out:
#                                RF  RF std    SVM  SVM std    kNN  kNN std  \
# Experiment 1                69.46    6.87  55.06     6.02  74.69     6.98
# Experiment 2_1 Delta        95.68    1.58  63.81     7.10  94.82     1.82
# Experiment 2_1 Theta        95.51    1.67  70.36     8.25  94.93     1.69
# Experiment 2_1 Alpha        95.50    1.74  74.91     8.58  94.96     1.80
# Experiment 2_1 Beta         95.39    1.55  94.42     3.70  94.90     1.62
# Experiment 2_1 Gamma        95.41    1.84  93.42     4.54  95.20     1.76
# Experiment 3_2 (All bands)  95.57    1.66  95.45     1.62  95.05     1.64
# Experiment 4_1 Own          95.80    1.66  95.62     1.87  95.50     1.69
# Experiment 4_1 Literature   95.81    1.58  91.68     4.42  95.43     1.42
#
#                             RF Happy  RF Happy std  SVM Happy  SVM Happy std  \
# Experiment 1                   74.68         16.85      59.57          11.65
# ...

# %%
df2['SVM Happy std']
# Out:
# Experiment 1                  76.97
# Experiment 2_1 Delta          95.09
# Experiment 2_1 Theta          95.20
# Experiment 2_1 Alpha          95.20
# Experiment 2_1 Beta           95.22
# Experiment 2_1 Gamma          95.49
# Experiment 3_2 (All bands)    95.25
# Experiment 4_1 Own            95.50
# Experiment 4_1 Literature     95.43
# Name: kNN Happy, dtype: float64
