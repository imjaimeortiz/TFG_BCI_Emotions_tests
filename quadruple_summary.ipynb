# %%
import pandas as pd
import statistics
import numpy as np
from statistics import mean

exp5_df = pd.read_csv("Experiment5.csv")
exp5_1_df = pd.read_csv("Experiment5_1.csv")
exp6_df = pd.read_csv("Experiment6.csv")
exp6_1_df = pd.read_csv("Experiment6_1.csv")
exp7_df = pd.read_csv("Experiment7.csv")
exp7_1_df = pd.read_csv("Experiment7_1.csv")

# %%
rf_acc_means = []
svm_acc_means = []
knn_acc_means = []

rf_sadness_means = []
rf_pleasure_means = []
rf_anger_means = []
rf_joy_means = []
svm_sadness_means = []
svm_pleasure_means = []
svm_anger_means = []
svm_joy_means = []
knn_sadness_means = []
knn_pleasure_means = []
knn_anger_means = []
knn_joy_means = []

# %%
exp5_df
# Out:
#      Subject  Experiment ID Feature extraction Band selection  \
# 0          1              5               STFT          Delta
# 1          1              5               STFT          Delta
# 2          1              5               STFT          Delta
# 3          1              5               STFT          theta
# 4          1              5               STFT          theta
# ..       ...            ...                ...            ...
# 475       32              5               STFT           beta
# 476       32              5               STFT           beta
# 477       32              5               STFT          gamma
# 478       32              5               STFT          gamma
# 479       32              5               STFT          gamma
#
#     Channel selection Classification algorithm  Accuracy  Sadness precision  \
# 0                   -            Random Forest  0.589844           0.857143
# ...

# %%
rf_acc_arr_delta = []
svm_acc_arr_delta = []
knn_acc_arr_delta = []
rf_acc_arr_theta = []
svm_acc_arr_theta = []
knn_acc_arr_theta = []
rf_acc_arr_alpha = []
svm_acc_arr_alpha = []
knn_acc_arr_alpha = []
rf_acc_arr_beta = []
svm_acc_arr_beta = []
knn_acc_arr_beta = []
rf_acc_arr_gamma = []
svm_acc_arr_gamma = []
knn_acc_arr_gamma = []

rf_sadness_arr_delta = []
svm_sadness_arr_delta = []
knn_sadness_arr_delta = []
rf_sadness_arr_theta = []
svm_sadness_arr_theta = []
knn_sadness_arr_theta = []
rf_sadness_arr_alpha = []
svm_sadness_arr_alpha = []
knn_sadness_arr_alpha = []
rf_sadness_arr_beta = []
svm_sadness_arr_beta = []
knn_sadness_arr_beta = []
rf_sadness_arr_gamma = []
svm_sadness_arr_gamma = []
knn_sadness_arr_gamma = []

rf_pleasure_arr_delta = []
svm_pleasure_arr_delta = []
knn_pleasure_arr_delta = []
rf_pleasure_arr_theta = []
svm_pleasure_arr_theta = []
knn_pleasure_arr_theta = []
rf_pleasure_arr_alpha = []
svm_pleasure_arr_alpha = []
knn_pleasure_arr_alpha = []
rf_pleasure_arr_beta = []
svm_pleasure_arr_beta = []
knn_pleasure_arr_beta = []
rf_pleasure_arr_gamma = []
svm_pleasure_arr_gamma = []
knn_pleasure_arr_gamma = []

rf_anger_arr_delta = []
svm_anger_arr_delta = []
knn_anger_arr_delta = []
rf_anger_arr_theta = []
svm_anger_arr_theta = []
knn_anger_arr_theta = []
rf_anger_arr_alpha = []
svm_anger_arr_alpha = []
knn_anger_arr_alpha = []
rf_anger_arr_beta = []
svm_anger_arr_beta = []
knn_anger_arr_beta = []
rf_anger_arr_gamma = []
svm_anger_arr_gamma = []
knn_anger_arr_gamma = []

rf_joy_arr_delta = []
svm_joy_arr_delta = []
knn_joy_arr_delta = []
rf_joy_arr_theta = []
svm_joy_arr_theta = []
knn_joy_arr_theta = []
rf_joy_arr_alpha = []
svm_joy_arr_alpha = []
knn_joy_arr_alpha = []
rf_joy_arr_beta = []
svm_joy_arr_beta = []
knn_joy_arr_beta = []
rf_joy_arr_gamma = []
svm_joy_arr_gamma = []
knn_joy_arr_gamma = []

exp5_acc = exp5_df['Accuracy']
exp5_sadness = exp5_df['Sadness precision']
exp5_pleasure = exp5_df['Pleasure precision']
exp5_anger = exp5_df['Anger precision']
exp5_joy = exp5_df['Joy precision']

print(len(exp5_acc))
for i in range (0,len(exp5_acc)):
    if (i%15 == 0):
        rf_acc_arr_delta.append(exp5_acc[i])
        rf_sadness_arr_delta.append(exp5_sadness[i])
        rf_pleasure_arr_delta.append(exp5_pleasure[i])
        rf_anger_arr_delta.append(exp5_anger[i])
        rf_joy_arr_delta.append(exp5_joy[i])
    if (i%15 == 1):
        svm_acc_arr_delta.append(exp5_acc[i])
        svm_sadness_arr_delta.append(exp5_sadness[i])
        svm_pleasure_arr_delta.append(exp5_pleasure[i])
        svm_anger_arr_delta.append(exp5_anger[i])
        svm_joy_arr_delta.append(exp5_joy[i])
    if (i%15 == 2):
        knn_acc_arr_delta.append(exp5_acc[i])
        knn_sadness_arr_delta.append(exp5_sadness[i])
        knn_pleasure_arr_delta.append(exp5_pleasure[i])
        knn_anger_arr_delta.append(exp5_anger[i])
        knn_joy_arr_delta.append(exp5_joy[i])
    if (i%15 == 3):
        rf_acc_arr_theta.append(exp5_acc[i])
        rf_sadness_arr_theta.append(exp5_sadness[i])
        rf_pleasure_arr_theta.append(exp5_pleasure[i])
        rf_anger_arr_theta.append(exp5_anger[i])
        rf_joy_arr_theta.append(exp5_joy[i])
    if (i%15 == 4):
        svm_acc_arr_theta.append(exp5_acc[i])
        svm_sadness_arr_theta.append(exp5_sadness[i])
        svm_pleasure_arr_theta.append(exp5_pleasure[i])
        svm_anger_arr_theta.append(exp5_anger[i])
        svm_joy_arr_theta.append(exp5_joy[i])
    if (i%15 == 5):
        knn_acc_arr_theta.append(exp5_acc[i])
        knn_sadness_arr_theta.append(exp5_sadness[i])
        knn_pleasure_arr_theta.append(exp5_pleasure[i])
        knn_anger_arr_theta.append(exp5_anger[i])
        knn_joy_arr_theta.append(exp5_joy[i])
    if (i%15 == 6):
        rf_acc_arr_alpha.append(exp5_acc[i])
        rf_sadness_arr_alpha.append(exp5_sadness[i])
        rf_pleasure_arr_alpha.append(exp5_pleasure[i])
        rf_anger_arr_alpha.append(exp5_anger[i])
        rf_joy_arr_alpha.append(exp5_joy[i])
    if (i%15 == 7):
        svm_acc_arr_alpha.append(exp5_acc[i])
        svm_sadness_arr_alpha.append(exp5_sadness[i])
        svm_pleasure_arr_alpha.append(exp5_pleasure[i])
        svm_anger_arr_alpha.append(exp5_anger[i])
        svm_joy_arr_alpha.append(exp5_joy[i])
    if (i%15 == 8):
        knn_acc_arr_alpha.append(exp5_acc[i])
        knn_sadness_arr_alpha.append(exp5_sadness[i])
        knn_pleasure_arr_alpha.append(exp5_pleasure[i])
        knn_anger_arr_alpha.append(exp5_anger[i])
        knn_joy_arr_alpha.append(exp5_joy[i])
    if (i%15 == 9):
        rf_acc_arr_beta.append(exp5_acc[i])
        rf_sadness_arr_beta.append(exp5_sadness[i])
        rf_pleasure_arr_beta.append(exp5_pleasure[i])
        rf_anger_arr_beta.append(exp5_anger[i])
        rf_joy_arr_beta.append(exp5_joy[i])
    if (i%15 == 10):
        svm_acc_arr_beta.append(exp5_acc[i])
        svm_sadness_arr_beta.append(exp5_sadness[i])
        svm_pleasure_arr_beta.append(exp5_pleasure[i])
        svm_anger_arr_beta.append(exp5_anger[i])
        svm_joy_arr_beta.append(exp5_joy[i])
    if (i%15 == 11):
        knn_acc_arr_beta.append(exp5_acc[i])
        knn_sadness_arr_beta.append(exp5_sadness[i])
        knn_pleasure_arr_beta.append(exp5_pleasure[i])
        knn_anger_arr_beta.append(exp5_anger[i])
        knn_joy_arr_beta.append(exp5_joy[i])
    if (i%15 == 12):
        rf_acc_arr_gamma.append(exp5_acc[i])
        rf_sadness_arr_gamma.append(exp5_sadness[i])
        rf_pleasure_arr_gamma.append(exp5_pleasure[i])
        rf_anger_arr_gamma.append(exp5_anger[i])
        rf_joy_arr_gamma.append(exp5_joy[i])
    if (i%15 == 13):
        svm_acc_arr_gamma.append(exp5_acc[i])
        svm_sadness_arr_gamma.append(exp5_sadness[i])
        svm_pleasure_arr_gamma.append(exp5_pleasure[i])
        svm_anger_arr_gamma.append(exp5_anger[i])
        svm_joy_arr_gamma.append(exp5_joy[i])
    if (i%15 == 14):
        knn_acc_arr_gamma.append(exp5_acc[i])
        knn_sadness_arr_gamma.append(exp5_sadness[i])
        knn_pleasure_arr_gamma.append(exp5_pleasure[i])
        knn_anger_arr_gamma.append(exp5_anger[i])
        knn_joy_arr_gamma.append(exp5_joy[i])
# Out:
# 480

# %%
rf_mean_delta = statistics.mean(rf_acc_arr_delta)
print("RF mean delta: ", rf_mean_delta)
svm_mean_delta = statistics.mean(svm_acc_arr_delta)
print("SVM mean delta: ", svm_mean_delta)
knn_mean_delta = statistics.mean(knn_acc_arr_delta)
print("kNN mean delta: ",knn_mean_delta)

rf_mean_theta = statistics.mean(rf_acc_arr_theta)
print("RF mean theta: ", rf_mean_theta)
svm_mean_theta = statistics.mean(svm_acc_arr_theta)
print("SVM mean theta: ", svm_mean_theta)
knn_mean_theta = statistics.mean(knn_acc_arr_theta)
print("kNN mean theta: ",knn_mean_theta)

rf_mean_alpha = statistics.mean(rf_acc_arr_alpha)
print("RF mean alpha: ", rf_mean_alpha)
svm_mean_alpha = statistics.mean(svm_acc_arr_alpha)
print("SVM mean alpha: ", svm_mean_alpha)
knn_mean_alpha = statistics.mean(knn_acc_arr_alpha)
print("kNN mean alpha: ",knn_mean_alpha)

rf_mean_beta = statistics.mean(rf_acc_arr_beta)
print("RF mean beta: ", rf_mean_beta)
svm_mean_beta = statistics.mean(svm_acc_arr_beta)
print("SVM mean beta: ", svm_mean_beta)
knn_mean_beta = statistics.mean(knn_acc_arr_beta)
print("kNN mean beta: ",knn_mean_beta)

rf_mean_gamma = statistics.mean(rf_acc_arr_gamma)
print("RF mean gamma: ", rf_mean_gamma)
svm_mean_gamma = statistics.mean(svm_acc_arr_gamma)
print("SVM mean gamma: ", svm_mean_gamma)
knn_mean_gamma = statistics.mean(knn_acc_arr_gamma)
print("kNN mean gamma: ",knn_mean_gamma)

rf_acc_means.append(rf_mean_delta)
rf_acc_means.append(rf_mean_theta)
rf_acc_means.append(rf_mean_alpha)
rf_acc_means.append(rf_mean_beta)
rf_acc_means.append(rf_mean_gamma)

svm_acc_means.append(svm_mean_delta)
svm_acc_means.append(svm_mean_theta)
svm_acc_means.append(svm_mean_alpha)
svm_acc_means.append(svm_mean_beta)
svm_acc_means.append(svm_mean_gamma)

knn_acc_means.append(knn_mean_delta)
knn_acc_means.append(knn_mean_theta)
knn_acc_means.append(knn_mean_alpha)
knn_acc_means.append(knn_mean_beta)
knn_acc_means.append(knn_mean_gamma)

print(len(rf_sadness_means))
print(len(rf_pleasure_means))

rf_sadness_delta = statistics.mean(rf_sadness_arr_delta)
print("RF sadness delta: ", rf_sadness_delta)
svm_sadness_delta = statistics.mean(svm_sadness_arr_delta)
print("SVM sadness delta: ", svm_sadness_delta)
knn_sadness_delta = statistics.mean(knn_sadness_arr_delta)
print("kNN sadness delta: ",knn_sadness_delta)

rf_sadness_theta = statistics.mean(rf_sadness_arr_theta)
print("RF sadness theta: ", rf_sadness_theta)
svm_sadness_theta = statistics.mean(svm_sadness_arr_theta)
print("SVM sadness theta: ", svm_sadness_theta)
knn_sadness_theta = statistics.mean(knn_sadness_arr_theta)
print("kNN sadness theta: ",knn_sadness_theta)

rf_sadness_alpha = statistics.mean(rf_sadness_arr_alpha)
print("RF sadness alpha: ", rf_sadness_alpha)
svm_sadness_alpha = statistics.mean(svm_sadness_arr_alpha)
print("SVM sadness alpha: ", svm_sadness_alpha)
knn_sadness_alpha = statistics.mean(knn_sadness_arr_alpha)
print("kNN sadness alpha: ",knn_sadness_alpha)

rf_sadness_beta = statistics.mean(rf_sadness_arr_beta)
print("RF sadness beta: ", rf_sadness_beta)
svm_sadness_beta = statistics.mean(svm_sadness_arr_beta)
print("SVM sadness beta: ", svm_sadness_beta)
knn_sadness_beta = statistics.mean(knn_sadness_arr_beta)
print("kNN sadness beta: ",knn_sadness_beta)

rf_sadness_gamma = statistics.mean(rf_sadness_arr_gamma)
print("RF sadness gamma: ", rf_sadness_gamma)
svm_sadness_gamma = statistics.mean(svm_sadness_arr_gamma)
print("SVM sadness gamma: ", svm_sadness_gamma)
knn_sadness_gamma = statistics.mean(knn_sadness_arr_gamma)
print("kNN sadness gamma: ",knn_sadness_gamma)

rf_sadness_means.append(rf_sadness_delta)
rf_sadness_means.append(rf_sadness_theta)
rf_sadness_means.append(rf_sadness_alpha)
rf_sadness_means.append(rf_sadness_beta)
rf_sadness_means.append(rf_sadness_gamma)

svm_sadness_means.append(svm_sadness_delta)
svm_sadness_means.append(svm_sadness_theta)
svm_sadness_means.append(svm_sadness_alpha)
svm_sadness_means.append(svm_sadness_beta)
svm_sadness_means.append(svm_sadness_gamma)

knn_sadness_means.append(knn_sadness_delta)
knn_sadness_means.append(knn_sadness_theta)
knn_sadness_means.append(knn_sadness_alpha)
knn_sadness_means.append(knn_sadness_beta)
knn_sadness_means.append(knn_sadness_gamma)

rf_pleasure_delta = statistics.mean(rf_pleasure_arr_delta)
print("RF pleasure delta: ", rf_pleasure_delta)
svm_pleasure_delta = statistics.mean(svm_pleasure_arr_delta)
print("SVM pleasure delta: ", svm_pleasure_delta)
knn_pleasure_delta = statistics.mean(knn_pleasure_arr_delta)
print("kNN pleasure delta: ",knn_pleasure_delta)

rf_pleasure_theta = statistics.mean(rf_pleasure_arr_theta)
print("RF pleasure theta: ", rf_pleasure_theta)
svm_pleasure_theta = statistics.mean(svm_pleasure_arr_theta)
print("SVM pleasure theta: ", svm_pleasure_theta)
knn_pleasure_theta = statistics.mean(knn_pleasure_arr_theta)
print("kNN pleasure theta: ",knn_pleasure_theta)

rf_pleasure_alpha = statistics.mean(rf_pleasure_arr_alpha)
print("RF pleasure alpha: ", rf_pleasure_alpha)
svm_pleasure_alpha = statistics.mean(svm_pleasure_arr_alpha)
print("SVM pleasure alpha: ", svm_pleasure_alpha)
knn_pleasure_alpha = statistics.mean(knn_pleasure_arr_alpha)
print("kNN pleasure alpha: ",knn_pleasure_alpha)

rf_pleasure_beta = statistics.mean(rf_pleasure_arr_beta)
print("RF pleasure beta: ", rf_pleasure_beta)
svm_pleasure_beta = statistics.mean(svm_pleasure_arr_beta)
print("SVM pleasure beta: ", svm_pleasure_beta)
knn_pleasure_beta = statistics.mean(knn_pleasure_arr_beta)
print("kNN pleasure beta: ",knn_pleasure_beta)

rf_pleasure_gamma = statistics.mean(rf_pleasure_arr_gamma)
print("RF pleasure gamma: ", rf_pleasure_gamma)
svm_pleasure_gamma = statistics.mean(svm_pleasure_arr_gamma)
print("SVM pleasure gamma: ", svm_pleasure_gamma)
knn_pleasure_gamma = statistics.mean(knn_pleasure_arr_gamma)
print("kNN pleasure gamma: ",knn_pleasure_gamma)

rf_pleasure_means.append(rf_pleasure_delta)
rf_pleasure_means.append(rf_pleasure_theta)
rf_pleasure_means.append(rf_pleasure_alpha)
rf_pleasure_means.append(rf_pleasure_beta)
rf_pleasure_means.append(rf_pleasure_gamma)

svm_pleasure_means.append(svm_pleasure_delta)
svm_pleasure_means.append(svm_pleasure_theta)
svm_pleasure_means.append(svm_pleasure_alpha)
svm_pleasure_means.append(svm_pleasure_beta)
svm_pleasure_means.append(svm_pleasure_gamma)

knn_pleasure_means.append(knn_pleasure_delta)
knn_pleasure_means.append(knn_pleasure_theta)
knn_pleasure_means.append(knn_pleasure_alpha)
knn_pleasure_means.append(knn_pleasure_beta)
knn_pleasure_means.append(knn_pleasure_gamma)

rf_anger_delta = statistics.mean(rf_anger_arr_delta)
print("RF anger delta: ", rf_anger_delta)
svm_anger_delta = statistics.mean(svm_anger_arr_delta)
print("SVM anger delta: ", svm_anger_delta)
knn_anger_delta = statistics.mean(knn_anger_arr_delta)
print("kNN anger delta: ",knn_anger_delta)

rf_anger_theta = statistics.mean(rf_anger_arr_theta)
print("RF anger theta: ", rf_anger_theta)
svm_anger_theta = statistics.mean(svm_anger_arr_theta)
print("SVM anger theta: ", svm_anger_theta)
knn_anger_theta = statistics.mean(knn_anger_arr_theta)
print("kNN anger theta: ",knn_anger_theta)

rf_anger_alpha = statistics.mean(rf_anger_arr_alpha)
print("RF anger alpha: ", rf_anger_alpha)
svm_anger_alpha = statistics.mean(svm_anger_arr_alpha)
print("SVM anger alpha: ", svm_anger_alpha)
knn_anger_alpha = statistics.mean(knn_anger_arr_alpha)
print("kNN anger alpha: ",knn_anger_alpha)

rf_anger_beta = statistics.mean(rf_anger_arr_beta)
print("RF anger beta: ", rf_anger_beta)
svm_anger_beta = statistics.mean(svm_anger_arr_beta)
print("SVM anger beta: ", svm_anger_beta)
knn_anger_beta = statistics.mean(knn_anger_arr_beta)
print("kNN anger beta: ",knn_anger_beta)

rf_anger_gamma = statistics.mean(rf_anger_arr_gamma)
print("RF anger gamma: ", rf_anger_gamma)
svm_anger_gamma = statistics.mean(svm_anger_arr_gamma)
print("SVM anger gamma: ", svm_anger_gamma)
knn_anger_gamma = statistics.mean(knn_anger_arr_gamma)
print("kNN anger gamma: ",knn_anger_gamma)

rf_anger_means.append(rf_anger_delta)
rf_anger_means.append(rf_anger_theta)
rf_anger_means.append(rf_anger_alpha)
rf_anger_means.append(rf_anger_beta)
rf_anger_means.append(rf_anger_gamma)

svm_anger_means.append(svm_anger_delta)
svm_anger_means.append(svm_anger_theta)
svm_anger_means.append(svm_anger_alpha)
svm_anger_means.append(svm_anger_beta)
svm_anger_means.append(svm_anger_gamma)

knn_anger_means.append(knn_anger_delta)
knn_anger_means.append(knn_anger_theta)
knn_anger_means.append(knn_anger_alpha)
knn_anger_means.append(knn_anger_beta)
knn_anger_means.append(knn_anger_gamma)

rf_joy_delta = statistics.mean(rf_joy_arr_delta)
print("RF joy delta: ", rf_joy_delta)
svm_joy_delta = statistics.mean(svm_joy_arr_delta)
print("SVM joy delta: ", svm_joy_delta)
knn_joy_delta = statistics.mean(knn_joy_arr_delta)
print("kNN joy delta: ",knn_joy_delta)

rf_joy_theta = statistics.mean(rf_joy_arr_theta)
print("RF joy theta: ", rf_joy_theta)
svm_joy_theta = statistics.mean(svm_joy_arr_theta)
print("SVM joy theta: ", svm_joy_theta)
knn_joy_theta = statistics.mean(knn_joy_arr_theta)
print("kNN joy theta: ",knn_joy_theta)

rf_joy_alpha = statistics.mean(rf_joy_arr_alpha)
print("RF joy alpha: ", rf_joy_alpha)
svm_joy_alpha = statistics.mean(svm_joy_arr_alpha)
print("SVM joy alpha: ", svm_joy_alpha)
knn_joy_alpha = statistics.mean(knn_joy_arr_alpha)
print("kNN joy alpha: ",knn_joy_alpha)

rf_joy_beta = statistics.mean(rf_joy_arr_beta)
print("RF joy beta: ", rf_joy_beta)
svm_joy_beta = statistics.mean(svm_joy_arr_beta)
print("SVM joy beta: ", svm_joy_beta)
knn_joy_beta = statistics.mean(knn_joy_arr_beta)
print("kNN joy beta: ",knn_joy_beta)

rf_joy_gamma = statistics.mean(rf_joy_arr_gamma)
print("RF joy gamma: ", rf_joy_gamma)
svm_joy_gamma = statistics.mean(svm_joy_arr_gamma)
print("SVM joy gamma: ", svm_joy_gamma)
knn_joy_gamma = statistics.mean(knn_joy_arr_gamma)
print("kNN joy gamma: ",knn_joy_gamma)

rf_joy_means.append(rf_joy_delta)
rf_joy_means.append(rf_joy_theta)
rf_joy_means.append(rf_joy_alpha)
rf_joy_means.append(rf_joy_beta)
rf_joy_means.append(rf_joy_gamma)

svm_joy_means.append(svm_joy_delta)
svm_joy_means.append(svm_joy_theta)
svm_joy_means.append(svm_joy_alpha)
svm_joy_means.append(svm_joy_beta)
svm_joy_means.append(svm_joy_gamma)

knn_joy_means.append(knn_joy_delta)
knn_joy_means.append(knn_joy_theta)
knn_joy_means.append(knn_joy_alpha)
knn_joy_means.append(knn_joy_beta)
knn_joy_means.append(knn_joy_gamma)
# Out:
# RF mean delta:  0.6180419921875
# SVM mean delta:  0.46533203125
# kNN mean delta:  0.91094970703125
# RF mean theta:  0.64141845703125
# SVM mean theta:  0.46502685546875
# kNN mean theta:  0.9136962890625
# RF mean alpha:  0.6458740234375
# SVM mean alpha:  0.46478271484375
# kNN mean alpha:  0.91180419921875
# RF mean beta:  0.635986328125
# SVM mean beta:  0.83709716796875
# kNN mean beta:  0.912353515625
# RF mean gamma:  0.63385009765625
# SVM mean gamma:  0.8731689453125
# kNN mean gamma:  0.91290283203125
# 0
# 0
# RF sadness delta:  0.5377555189495087
# SVM sadness delta:  0.1475319253438114
# kNN sadness delta:  0.8393011244267375
# RF sadness theta:  0.42092199167542665
# SVM sadness theta:  0.11628192534381139
# kNN sadness theta:  0.8541063718375965
# RF sadness alpha:  0.44561707746748935
# SVM sadness alpha:  0.11628192534381139
# kNN sadness alpha:  0.8653808891420847
# RF sadness beta:  0.288895498019735
# SVM sadness beta:  0.8420051608845879
# ...

# %%
rf_acc_arr_delta = []
svm_acc_arr_delta = []
knn_acc_arr_delta = []
rf_acc_arr_theta = []
svm_acc_arr_theta = []
knn_acc_arr_theta = []
rf_acc_arr_alpha = []
svm_acc_arr_alpha = []
knn_acc_arr_alpha = []
rf_acc_arr_beta = []
svm_acc_arr_beta = []
knn_acc_arr_beta = []
rf_acc_arr_gamma = []
svm_acc_arr_gamma = []
knn_acc_arr_gamma = []

rf_sadness_arr_delta = []
svm_sadness_arr_delta = []
knn_sadness_arr_delta = []
rf_sadness_arr_theta = []
svm_sadness_arr_theta = []
knn_sadness_arr_theta = []
rf_sadness_arr_alpha = []
svm_sadness_arr_alpha = []
knn_sadness_arr_alpha = []
rf_sadness_arr_beta = []
svm_sadness_arr_beta = []
knn_sadness_arr_beta = []
rf_sadness_arr_gamma = []
svm_sadness_arr_gamma = []
knn_sadness_arr_gamma = []

rf_pleasure_arr_delta = []
svm_pleasure_arr_delta = []
knn_pleasure_arr_delta = []
rf_pleasure_arr_theta = []
svm_pleasure_arr_theta = []
knn_pleasure_arr_theta = []
rf_pleasure_arr_alpha = []
svm_pleasure_arr_alpha = []
knn_pleasure_arr_alpha = []
rf_pleasure_arr_beta = []
svm_pleasure_arr_beta = []
knn_pleasure_arr_beta = []
rf_pleasure_arr_gamma = []
svm_pleasure_arr_gamma = []
knn_pleasure_arr_gamma = []

rf_anger_arr_delta = []
svm_anger_arr_delta = []
knn_anger_arr_delta = []
rf_anger_arr_theta = []
svm_anger_arr_theta = []
knn_anger_arr_theta = []
rf_anger_arr_alpha = []
svm_anger_arr_alpha = []
knn_anger_arr_alpha = []
rf_anger_arr_beta = []
svm_anger_arr_beta = []
knn_anger_arr_beta = []
rf_anger_arr_gamma = []
svm_anger_arr_gamma = []
knn_anger_arr_gamma = []

rf_joy_arr_delta = []
svm_joy_arr_delta = []
knn_joy_arr_delta = []
rf_joy_arr_theta = []
svm_joy_arr_theta = []
knn_joy_arr_theta = []
rf_joy_arr_alpha = []
svm_joy_arr_alpha = []
knn_joy_arr_alpha = []
rf_joy_arr_beta = []
svm_joy_arr_beta = []
knn_joy_arr_beta = []
rf_joy_arr_gamma = []
svm_joy_arr_gamma = []
knn_joy_arr_gamma = []

exp5_acc = exp5_1_df['Accuracy']
exp5_sadness = exp5_1_df['Sadness precision']
exp5_pleasure = exp5_1_df['Pleasure precision']
exp5_anger = exp5_1_df['Anger precision']
exp5_joy = exp5_1_df['Joy precision']

print(len(exp5_acc))
for i in range (0,len(exp5_acc)):
    if (i%15 == 0):
        rf_acc_arr_delta.append(exp5_acc[i])
        rf_sadness_arr_delta.append(exp5_sadness[i])
        rf_pleasure_arr_delta.append(exp5_pleasure[i])
        rf_anger_arr_delta.append(exp5_anger[i])
        rf_joy_arr_delta.append(exp5_joy[i])
    if (i%15 == 1):
        svm_acc_arr_delta.append(exp5_acc[i])
        svm_sadness_arr_delta.append(exp5_sadness[i])
        svm_pleasure_arr_delta.append(exp5_pleasure[i])
        svm_anger_arr_delta.append(exp5_anger[i])
        svm_joy_arr_delta.append(exp5_joy[i])
    if (i%15 == 2):
        knn_acc_arr_delta.append(exp5_acc[i])
        knn_sadness_arr_delta.append(exp5_sadness[i])
        knn_pleasure_arr_delta.append(exp5_pleasure[i])
        knn_anger_arr_delta.append(exp5_anger[i])
        knn_joy_arr_delta.append(exp5_joy[i])
    if (i%15 == 3):
        rf_acc_arr_theta.append(exp5_acc[i])
        rf_sadness_arr_theta.append(exp5_sadness[i])
        rf_pleasure_arr_theta.append(exp5_pleasure[i])
        rf_anger_arr_theta.append(exp5_anger[i])
        rf_joy_arr_theta.append(exp5_joy[i])
    if (i%15 == 4):
        svm_acc_arr_theta.append(exp5_acc[i])
        svm_sadness_arr_theta.append(exp5_sadness[i])
        svm_pleasure_arr_theta.append(exp5_pleasure[i])
        svm_anger_arr_theta.append(exp5_anger[i])
        svm_joy_arr_theta.append(exp5_joy[i])
    if (i%15 == 5):
        knn_acc_arr_theta.append(exp5_acc[i])
        knn_sadness_arr_theta.append(exp5_sadness[i])
        knn_pleasure_arr_theta.append(exp5_pleasure[i])
        knn_anger_arr_theta.append(exp5_anger[i])
        knn_joy_arr_theta.append(exp5_joy[i])
    if (i%15 == 6):
        rf_acc_arr_alpha.append(exp5_acc[i])
        rf_sadness_arr_alpha.append(exp5_sadness[i])
        rf_pleasure_arr_alpha.append(exp5_pleasure[i])
        rf_anger_arr_alpha.append(exp5_anger[i])
        rf_joy_arr_alpha.append(exp5_joy[i])
    if (i%15 == 7):
        svm_acc_arr_alpha.append(exp5_acc[i])
        svm_sadness_arr_alpha.append(exp5_sadness[i])
        svm_pleasure_arr_alpha.append(exp5_pleasure[i])
        svm_anger_arr_alpha.append(exp5_anger[i])
        svm_joy_arr_alpha.append(exp5_joy[i])
    if (i%15 == 8):
        knn_acc_arr_alpha.append(exp5_acc[i])
        knn_sadness_arr_alpha.append(exp5_sadness[i])
        knn_pleasure_arr_alpha.append(exp5_pleasure[i])
        knn_anger_arr_alpha.append(exp5_anger[i])
        knn_joy_arr_alpha.append(exp5_joy[i])
    if (i%15 == 9):
        rf_acc_arr_beta.append(exp5_acc[i])
        rf_sadness_arr_beta.append(exp5_sadness[i])
        rf_pleasure_arr_beta.append(exp5_pleasure[i])
        rf_anger_arr_beta.append(exp5_anger[i])
        rf_joy_arr_beta.append(exp5_joy[i])
    if (i%15 == 10):
        svm_acc_arr_beta.append(exp5_acc[i])
        svm_sadness_arr_beta.append(exp5_sadness[i])
        svm_pleasure_arr_beta.append(exp5_pleasure[i])
        svm_anger_arr_beta.append(exp5_anger[i])
        svm_joy_arr_beta.append(exp5_joy[i])
    if (i%15 == 11):
        knn_acc_arr_beta.append(exp5_acc[i])
        knn_sadness_arr_beta.append(exp5_sadness[i])
        knn_pleasure_arr_beta.append(exp5_pleasure[i])
        knn_anger_arr_beta.append(exp5_anger[i])
        knn_joy_arr_beta.append(exp5_joy[i])
    if (i%15 == 12):
        rf_acc_arr_gamma.append(exp5_acc[i])
        rf_sadness_arr_gamma.append(exp5_sadness[i])
        rf_pleasure_arr_gamma.append(exp5_pleasure[i])
        rf_anger_arr_gamma.append(exp5_anger[i])
        rf_joy_arr_gamma.append(exp5_joy[i])
    if (i%15 == 13):
        svm_acc_arr_gamma.append(exp5_acc[i])
        svm_sadness_arr_gamma.append(exp5_sadness[i])
        svm_pleasure_arr_gamma.append(exp5_pleasure[i])
        svm_anger_arr_gamma.append(exp5_anger[i])
        svm_joy_arr_gamma.append(exp5_joy[i])
    if (i%15 == 14):
        knn_acc_arr_gamma.append(exp5_acc[i])
        knn_sadness_arr_gamma.append(exp5_sadness[i])
        knn_pleasure_arr_gamma.append(exp5_pleasure[i])
        knn_anger_arr_gamma.append(exp5_anger[i])
        knn_joy_arr_gamma.append(exp5_joy[i])

rf_mean_delta = statistics.mean(rf_acc_arr_delta)
print("RF mean delta: ", rf_mean_delta)
svm_mean_delta = statistics.mean(svm_acc_arr_delta)
print("SVM mean delta: ", svm_mean_delta)
knn_mean_delta = statistics.mean(knn_acc_arr_delta)
print("kNN mean delta: ",knn_mean_delta)

rf_mean_theta = statistics.mean(rf_acc_arr_theta)
print("RF mean theta: ", rf_mean_theta)
svm_mean_theta = statistics.mean(svm_acc_arr_theta)
print("SVM mean theta: ", svm_mean_theta)
knn_mean_theta = statistics.mean(knn_acc_arr_theta)
print("kNN mean theta: ",knn_mean_theta)

rf_mean_alpha = statistics.mean(rf_acc_arr_alpha)
print("RF mean alpha: ", rf_mean_alpha)
svm_mean_alpha = statistics.mean(svm_acc_arr_alpha)
print("SVM mean alpha: ", svm_mean_alpha)
knn_mean_alpha = statistics.mean(knn_acc_arr_alpha)
print("kNN mean alpha: ",knn_mean_alpha)

rf_mean_beta = statistics.mean(rf_acc_arr_beta)
print("RF mean beta: ", rf_mean_beta)
svm_mean_beta = statistics.mean(svm_acc_arr_beta)
print("SVM mean beta: ", svm_mean_beta)
knn_mean_beta = statistics.mean(knn_acc_arr_beta)
print("kNN mean beta: ",knn_mean_beta)

rf_mean_gamma = statistics.mean(rf_acc_arr_gamma)
print("RF mean gamma: ", rf_mean_gamma)
svm_mean_gamma = statistics.mean(svm_acc_arr_gamma)
print("SVM mean gamma: ", svm_mean_gamma)
knn_mean_gamma = statistics.mean(knn_acc_arr_gamma)
print("kNN mean gamma: ",knn_mean_gamma)

rf_acc_means.append(rf_mean_delta)
rf_acc_means.append(rf_mean_theta)
rf_acc_means.append(rf_mean_alpha)
rf_acc_means.append(rf_mean_beta)
rf_acc_means.append(rf_mean_gamma)

svm_acc_means.append(svm_mean_delta)
svm_acc_means.append(svm_mean_theta)
svm_acc_means.append(svm_mean_alpha)
svm_acc_means.append(svm_mean_beta)
svm_acc_means.append(svm_mean_gamma)

knn_acc_means.append(knn_mean_delta)
knn_acc_means.append(knn_mean_theta)
knn_acc_means.append(knn_mean_alpha)
knn_acc_means.append(knn_mean_beta)
knn_acc_means.append(knn_mean_gamma)

print(len(rf_sadness_means))
print(len(rf_pleasure_means))

rf_sadness_delta = statistics.mean(rf_sadness_arr_delta)
print("RF sadness delta: ", rf_sadness_delta)
svm_sadness_delta = statistics.mean(svm_sadness_arr_delta)
print("SVM sadness delta: ", svm_sadness_delta)
knn_sadness_delta = statistics.mean(knn_sadness_arr_delta)
print("kNN sadness delta: ",knn_sadness_delta)

rf_sadness_theta = statistics.mean(rf_sadness_arr_theta)
print("RF sadness theta: ", rf_sadness_theta)
svm_sadness_theta = statistics.mean(svm_sadness_arr_theta)
print("SVM sadness theta: ", svm_sadness_theta)
knn_sadness_theta = statistics.mean(knn_sadness_arr_theta)
print("kNN sadness theta: ",knn_sadness_theta)

rf_sadness_alpha = statistics.mean(rf_sadness_arr_alpha)
print("RF sadness alpha: ", rf_sadness_alpha)
svm_sadness_alpha = statistics.mean(svm_sadness_arr_alpha)
print("SVM sadness alpha: ", svm_sadness_alpha)
knn_sadness_alpha = statistics.mean(knn_sadness_arr_alpha)
print("kNN sadness alpha: ",knn_sadness_alpha)

rf_sadness_beta = statistics.mean(rf_sadness_arr_beta)
print("RF sadness beta: ", rf_sadness_beta)
svm_sadness_beta = statistics.mean(svm_sadness_arr_beta)
print("SVM sadness beta: ", svm_sadness_beta)
knn_sadness_beta = statistics.mean(knn_sadness_arr_beta)
print("kNN sadness beta: ",knn_sadness_beta)

rf_sadness_gamma = statistics.mean(rf_sadness_arr_gamma)
print("RF sadness gamma: ", rf_sadness_gamma)
svm_sadness_gamma = statistics.mean(svm_sadness_arr_gamma)
print("SVM sadness gamma: ", svm_sadness_gamma)
knn_sadness_gamma = statistics.mean(knn_sadness_arr_gamma)
print("kNN sadness gamma: ",knn_sadness_gamma)

rf_sadness_means.append(rf_sadness_delta)
rf_sadness_means.append(rf_sadness_theta)
rf_sadness_means.append(rf_sadness_alpha)
rf_sadness_means.append(rf_sadness_beta)
rf_sadness_means.append(rf_sadness_gamma)

svm_sadness_means.append(svm_sadness_delta)
svm_sadness_means.append(svm_sadness_theta)
svm_sadness_means.append(svm_sadness_alpha)
svm_sadness_means.append(svm_sadness_beta)
svm_sadness_means.append(svm_sadness_gamma)

knn_sadness_means.append(knn_sadness_delta)
knn_sadness_means.append(knn_sadness_theta)
knn_sadness_means.append(knn_sadness_alpha)
knn_sadness_means.append(knn_sadness_beta)
knn_sadness_means.append(knn_sadness_gamma)

rf_pleasure_delta = statistics.mean(rf_pleasure_arr_delta)
print("RF pleasure delta: ", rf_pleasure_delta)
svm_pleasure_delta = statistics.mean(svm_pleasure_arr_delta)
print("SVM pleasure delta: ", svm_pleasure_delta)
knn_pleasure_delta = statistics.mean(knn_pleasure_arr_delta)
print("kNN pleasure delta: ",knn_pleasure_delta)

rf_pleasure_theta = statistics.mean(rf_pleasure_arr_theta)
print("RF pleasure theta: ", rf_pleasure_theta)
svm_pleasure_theta = statistics.mean(svm_pleasure_arr_theta)
print("SVM pleasure theta: ", svm_pleasure_theta)
knn_pleasure_theta = statistics.mean(knn_pleasure_arr_theta)
print("kNN pleasure theta: ",knn_pleasure_theta)

rf_pleasure_alpha = statistics.mean(rf_pleasure_arr_alpha)
print("RF pleasure alpha: ", rf_pleasure_alpha)
svm_pleasure_alpha = statistics.mean(svm_pleasure_arr_alpha)
print("SVM pleasure alpha: ", svm_pleasure_alpha)
knn_pleasure_alpha = statistics.mean(knn_pleasure_arr_alpha)
print("kNN pleasure alpha: ",knn_pleasure_alpha)

rf_pleasure_beta = statistics.mean(rf_pleasure_arr_beta)
print("RF pleasure beta: ", rf_pleasure_beta)
svm_pleasure_beta = statistics.mean(svm_pleasure_arr_beta)
print("SVM pleasure beta: ", svm_pleasure_beta)
knn_pleasure_beta = statistics.mean(knn_pleasure_arr_beta)
print("kNN pleasure beta: ",knn_pleasure_beta)

rf_pleasure_gamma = statistics.mean(rf_pleasure_arr_gamma)
print("RF pleasure gamma: ", rf_pleasure_gamma)
svm_pleasure_gamma = statistics.mean(svm_pleasure_arr_gamma)
print("SVM pleasure gamma: ", svm_pleasure_gamma)
knn_pleasure_gamma = statistics.mean(knn_pleasure_arr_gamma)
print("kNN pleasure gamma: ",knn_pleasure_gamma)

rf_pleasure_means.append(rf_pleasure_delta)
rf_pleasure_means.append(rf_pleasure_theta)
rf_pleasure_means.append(rf_pleasure_alpha)
rf_pleasure_means.append(rf_pleasure_beta)
rf_pleasure_means.append(rf_pleasure_gamma)

svm_pleasure_means.append(svm_pleasure_delta)
svm_pleasure_means.append(svm_pleasure_theta)
svm_pleasure_means.append(svm_pleasure_alpha)
svm_pleasure_means.append(svm_pleasure_beta)
svm_pleasure_means.append(svm_pleasure_gamma)

knn_pleasure_means.append(knn_pleasure_delta)
knn_pleasure_means.append(knn_pleasure_theta)
knn_pleasure_means.append(knn_pleasure_alpha)
knn_pleasure_means.append(knn_pleasure_beta)
knn_pleasure_means.append(knn_pleasure_gamma)

rf_anger_delta = statistics.mean(rf_anger_arr_delta)
print("RF anger delta: ", rf_anger_delta)
svm_anger_delta = statistics.mean(svm_anger_arr_delta)
print("SVM anger delta: ", svm_anger_delta)
knn_anger_delta = statistics.mean(knn_anger_arr_delta)
print("kNN anger delta: ",knn_anger_delta)

rf_anger_theta = statistics.mean(rf_anger_arr_theta)
print("RF anger theta: ", rf_anger_theta)
svm_anger_theta = statistics.mean(svm_anger_arr_theta)
print("SVM anger theta: ", svm_anger_theta)
knn_anger_theta = statistics.mean(knn_anger_arr_theta)
print("kNN anger theta: ",knn_anger_theta)

rf_anger_alpha = statistics.mean(rf_anger_arr_alpha)
print("RF anger alpha: ", rf_anger_alpha)
svm_anger_alpha = statistics.mean(svm_anger_arr_alpha)
print("SVM anger alpha: ", svm_anger_alpha)
knn_anger_alpha = statistics.mean(knn_anger_arr_alpha)
print("kNN anger alpha: ",knn_anger_alpha)

rf_anger_beta = statistics.mean(rf_anger_arr_beta)
print("RF anger beta: ", rf_anger_beta)
svm_anger_beta = statistics.mean(svm_anger_arr_beta)
print("SVM anger beta: ", svm_anger_beta)
knn_anger_beta = statistics.mean(knn_anger_arr_beta)
print("kNN anger beta: ",knn_anger_beta)

rf_anger_gamma = statistics.mean(rf_anger_arr_gamma)
print("RF anger gamma: ", rf_anger_gamma)
svm_anger_gamma = statistics.mean(svm_anger_arr_gamma)
print("SVM anger gamma: ", svm_anger_gamma)
knn_anger_gamma = statistics.mean(knn_anger_arr_gamma)
print("kNN anger gamma: ",knn_anger_gamma)

rf_anger_means.append(rf_anger_delta)
rf_anger_means.append(rf_anger_theta)
rf_anger_means.append(rf_anger_alpha)
rf_anger_means.append(rf_anger_beta)
rf_anger_means.append(rf_anger_gamma)

svm_anger_means.append(svm_anger_delta)
svm_anger_means.append(svm_anger_theta)
svm_anger_means.append(svm_anger_alpha)
svm_anger_means.append(svm_anger_beta)
svm_anger_means.append(svm_anger_gamma)

knn_anger_means.append(knn_anger_delta)
knn_anger_means.append(knn_anger_theta)
knn_anger_means.append(knn_anger_alpha)
knn_anger_means.append(knn_anger_beta)
knn_anger_means.append(knn_anger_gamma)

rf_joy_delta = statistics.mean(rf_joy_arr_delta)
print("RF joy delta: ", rf_joy_delta)
svm_joy_delta = statistics.mean(svm_joy_arr_delta)
print("SVM joy delta: ", svm_joy_delta)
knn_joy_delta = statistics.mean(knn_joy_arr_delta)
print("kNN joy delta: ",knn_joy_delta)

rf_joy_theta = statistics.mean(rf_joy_arr_theta)
print("RF joy theta: ", rf_joy_theta)
svm_joy_theta = statistics.mean(svm_joy_arr_theta)
print("SVM joy theta: ", svm_joy_theta)
knn_joy_theta = statistics.mean(knn_joy_arr_theta)
print("kNN joy theta: ",knn_joy_theta)

rf_joy_alpha = statistics.mean(rf_joy_arr_alpha)
print("RF joy alpha: ", rf_joy_alpha)
svm_joy_alpha = statistics.mean(svm_joy_arr_alpha)
print("SVM joy alpha: ", svm_joy_alpha)
knn_joy_alpha = statistics.mean(knn_joy_arr_alpha)
print("kNN joy alpha: ",knn_joy_alpha)

rf_joy_beta = statistics.mean(rf_joy_arr_beta)
print("RF joy beta: ", rf_joy_beta)
svm_joy_beta = statistics.mean(svm_joy_arr_beta)
print("SVM joy beta: ", svm_joy_beta)
knn_joy_beta = statistics.mean(knn_joy_arr_beta)
print("kNN joy beta: ",knn_joy_beta)

rf_joy_gamma = statistics.mean(rf_joy_arr_gamma)
print("RF joy gamma: ", rf_joy_gamma)
svm_joy_gamma = statistics.mean(svm_joy_arr_gamma)
print("SVM joy gamma: ", svm_joy_gamma)
knn_joy_gamma = statistics.mean(knn_joy_arr_gamma)
print("kNN joy gamma: ",knn_joy_gamma)

rf_joy_means.append(rf_joy_delta)
rf_joy_means.append(rf_joy_theta)
rf_joy_means.append(rf_joy_alpha)
rf_joy_means.append(rf_joy_beta)
rf_joy_means.append(rf_joy_gamma)

svm_joy_means.append(svm_joy_delta)
svm_joy_means.append(svm_joy_theta)
svm_joy_means.append(svm_joy_alpha)
svm_joy_means.append(svm_joy_beta)
svm_joy_means.append(svm_joy_gamma)

knn_joy_means.append(knn_joy_delta)
knn_joy_means.append(knn_joy_theta)
knn_joy_means.append(knn_joy_alpha)
knn_joy_means.append(knn_joy_beta)
knn_joy_means.append(knn_joy_gamma)
# Out:
# 450
# RF mean delta:  0.9125
# SVM mean delta:  0.5076822916666667
# kNN mean delta:  0.9158203125
# RF mean theta:  0.9225911458333333
# SVM mean theta:  0.5182942708333333
# kNN mean theta:  0.9171223958333333
# RF mean alpha:  0.9250651041666667
# SVM mean alpha:  0.5764322916666667
# kNN mean alpha:  0.9165364583333333
# RF mean beta:  0.922265625
# SVM mean beta:  0.917578125
# kNN mean beta:  0.9143229166666667
# RF mean gamma:  0.92265625
# SVM mean gamma:  0.917578125
# kNN mean gamma:  0.9160807291666667
# 5
# 5
# RF sadness delta:  0.8577098107047191
# SVM sadness delta:  0.13452424618625736
# kNN sadness delta:  0.8434935836773868
# RF sadness theta:  0.8629418081418634
# SVM sadness theta:  0.1895102525698844
# kNN sadness theta:  0.8447434923042837
# RF sadness alpha:  0.854062818272017
# SVM sadness alpha:  0.2740174347298058
# kNN sadness alpha:  0.833602122841628
# RF sadness beta:  0.8599713944265461
# SVM sadness beta:  0.8517680842653192
# ...

# %%
exp6_df
# Out:
#     Subject  Experiment ID Feature extraction Band selection  \
# 0         1              6               STFT      All bands
# 1         1              6               STFT      All bands
# 2         1              6               STFT      All bands
# 3         2              6               STFT      All bands
# 4         2              6               STFT      All bands
# ..      ...            ...                ...            ...
# 91       31              6               STFT      All bands
# 92       31              6               STFT      All bands
# 93       32              6               STFT      All bands
# 94       32              6               STFT      All bands
# 95       32              6               STFT      All bands
#
#    Channel selection Classification algorithm  Accuracy  Sadness precision  \
# 0                  -            Random Forest  0.740234           0.785047
# 1                  -                      SVM  0.939453           0.946429
# ...

# %%
rf_acc_arr_6 = []
svm_acc_arr_6 = []
knn_acc_arr_6 = []

rf_sadness_arr_6 = []
svm_sadness_arr_6 = []
knn_sadness_arr_6 = []

rf_pleasure_arr_6 = []
svm_pleasure_arr_6 = []
knn_pleasure_arr_6 = []

rf_anger_arr_6 = []
svm_anger_arr_6 = []
knn_anger_arr_6 = []

rf_joy_arr_6 = []
svm_joy_arr_6 = []
knn_joy_arr_6 = []

exp6_acc = exp6_df['Accuracy']
exp6_sadness = exp6_df['Sadness precision']
exp6_pleasure = exp6_df['Pleasure precision']
exp6_anger = exp6_df['Anger precision']
exp6_joy = exp6_df['Joy precision']

print(len(exp6_acc))
for i in range (0,len(exp6_acc)):
    if (i%6 == 0):
        rf_acc_arr_6.append(exp6_acc[i])
        rf_sadness_arr_6.append(exp6_sadness[i])
        rf_pleasure_arr_6.append(exp6_pleasure[i])
        rf_anger_arr_6.append(exp6_anger[i])
        rf_joy_arr_6.append(exp6_joy[i])
    if (i%6 == 1):
        svm_acc_arr_6.append(exp6_acc[i])
        svm_sadness_arr_6.append(exp6_sadness[i])
        svm_pleasure_arr_6.append(exp6_pleasure[i])
        svm_anger_arr_6.append(exp6_anger[i])
        svm_joy_arr_6.append(exp6_joy[i])
    if (i%6 == 2):
        knn_acc_arr_6.append(exp6_acc[i])
        knn_sadness_arr_6.append(exp6_sadness[i])
        knn_pleasure_arr_6.append(exp6_pleasure[i])
        knn_anger_arr_6.append(exp6_anger[i])
        knn_joy_arr_6.append(exp6_joy[i])

print(rf_acc_arr_6)
print(svm_acc_arr_6)
print(knn_acc_arr_6)
# Out:
# 96
# [0.740234375, 0.703125, 0.56640625, 0.60546875, 0.630859375, 0.515625, 0.736328125, 0.71875, 0.634765625, 0.619140625, 0.689453125, 0.822265625, 0.701171875, 0.654296875, 0.689453125, 0.787109375]
# [0.939453125, 0.947265625, 0.908203125, 0.90625, 0.869140625, 0.822265625, 0.93359375, 0.9375, 0.875, 0.951171875, 0.892578125, 0.892578125, 0.91796875, 0.935546875, 0.955078125, 0.931640625]
# [0.93359375, 0.943359375, 0.91015625, 0.90234375, 0.89453125, 0.89453125, 0.904296875, 0.923828125, 0.9375, 0.939453125, 0.908203125, 0.89453125, 0.9296875, 0.912109375, 0.923828125, 0.9375]

# %%
rf_mean_6 = statistics.mean(rf_acc_arr_6)
print("RF mean: ", rf_mean_6)
svm_mean_6 = statistics.mean(svm_acc_arr_6)
print("SVM mean: ", svm_mean_6)
knn_mean_6 = statistics.mean(knn_acc_arr_6)
print("kNN mean: ", knn_mean_6)

rf_acc_means.append(rf_mean_6)
svm_acc_means.append(svm_mean_6)
knn_acc_means.append(knn_mean_6)

rf_sadness_mean6 = statistics.mean(rf_sadness_arr_6)
print("RF mean: ", rf_sadness_mean6)
svm_sadness_mean6 = statistics.mean(svm_sadness_arr_6)
print("SVM mean: ", svm_sadness_mean6)
knn_sadness_mean6 = statistics.mean(knn_sadness_arr_6)
print("kNN mean: ", knn_sadness_mean6)

rf_sadness_means.append(rf_sadness_mean6)
svm_sadness_means.append(svm_sadness_mean6)
knn_sadness_means.append(knn_sadness_mean6)

rf_pleasure_mean6 = statistics.mean(rf_pleasure_arr_6)
print("RF mean: ", rf_pleasure_mean6)
svm_pleasure_mean6 = statistics.mean(svm_pleasure_arr_6)
print("SVM mean: ", svm_pleasure_mean6)
knn_pleasure_mean6 = statistics.mean(knn_pleasure_arr_6)
print("kNN mean: ", knn_pleasure_mean6)

rf_pleasure_means.append(rf_pleasure_mean6)
svm_pleasure_means.append(svm_pleasure_mean6)
knn_pleasure_means.append(knn_pleasure_mean6)

rf_anger_mean6 = statistics.mean(rf_anger_arr_6)
print("RF mean: ", rf_anger_mean6)
svm_anger_mean6 = statistics.mean(svm_anger_arr_6)
print("SVM mean: ", svm_anger_mean6)
knn_anger_mean6 = statistics.mean(knn_anger_arr_6)
print("kNN mean: ", knn_anger_mean6)

rf_anger_means.append(rf_anger_mean6)
svm_anger_means.append(svm_anger_mean6)
knn_anger_means.append(knn_anger_mean6)

rf_joy_mean6 = statistics.mean(rf_joy_arr_6)
print("RF mean: ", rf_joy_mean6)
svm_joy_mean6 = statistics.mean(svm_joy_arr_6)
print("SVM mean: ", svm_joy_mean6)
knn_joy_mean6 = statistics.mean(knn_joy_arr_6)
print("kNN mean: ", knn_joy_mean6)

rf_joy_means.append(rf_joy_mean6)
svm_joy_means.append(svm_joy_mean6)
knn_joy_means.append(knn_joy_mean6)
# Out:
# RF mean:  0.6759033203125
# SVM mean:  0.9134521484375
# kNN mean:  0.9180908203125
# RF mean:  0.5835038263578491
# SVM mean:  0.8517513389603422
# kNN mean:  0.857939773603981
# RF mean:  0.6290706850579064
# SVM mean:  0.8510200499779604
# kNN mean:  0.847957915998684
# RF mean:  0.46320415360791645
# SVM mean:  0.879684281115714
# kNN mean:  0.8911260723770204
# RF mean:  0.6518870407675422
# SVM mean:  0.9167998197629614
# kNN mean:  0.9248898508392865

# %%
rf_acc_arr_6 = []
svm_acc_arr_6 = []
knn_acc_arr_6 = []

rf_sadness_arr_6 = []
svm_sadness_arr_6 = []
knn_sadness_arr_6 = []

rf_pleasure_arr_6 = []
svm_pleasure_arr_6 = []
knn_pleasure_arr_6 = []

rf_anger_arr_6 = []
svm_anger_arr_6 = []
knn_anger_arr_6 = []

rf_joy_arr_6 = []
svm_joy_arr_6 = []
knn_joy_arr_6 = []

exp6_acc = exp6_1_df['Accuracy']
exp6_sadness = exp6_1_df['Sadness precision']
exp6_pleasure = exp6_1_df['Pleasure precision']
exp6_anger = exp6_1_df['Anger precision']
exp6_joy = exp6_1_df['Joy precision']

print(len(exp6_acc))
for i in range (0,len(exp6_acc)):
    if (i%6 == 0):
        rf_acc_arr_6.append(exp6_acc[i])
        rf_sadness_arr_6.append(exp6_sadness[i])
        rf_pleasure_arr_6.append(exp6_pleasure[i])
        rf_anger_arr_6.append(exp6_anger[i])
        rf_joy_arr_6.append(exp6_joy[i])
    if (i%6 == 1):
        svm_acc_arr_6.append(exp6_acc[i])
        svm_sadness_arr_6.append(exp6_sadness[i])
        svm_pleasure_arr_6.append(exp6_pleasure[i])
        svm_anger_arr_6.append(exp6_anger[i])
        svm_joy_arr_6.append(exp6_joy[i])
    if (i%6 == 2):
        knn_acc_arr_6.append(exp6_acc[i])
        knn_sadness_arr_6.append(exp6_sadness[i])
        knn_pleasure_arr_6.append(exp6_pleasure[i])
        knn_anger_arr_6.append(exp6_anger[i])
        knn_joy_arr_6.append(exp6_joy[i])

print(rf_acc_arr_6)
print(svm_acc_arr_6)
print(knn_acc_arr_6)
# Out:
# 96
# [0.939453125, 0.947265625, 0.91015625, 0.90625, 0.9140625, 0.90625, 0.93359375, 0.9375, 0.9375, 0.951171875, 0.908203125, 0.9140625, 0.931640625, 0.91015625, 0.955078125, 0.931640625]
# [0.939453125, 0.947265625, 0.91015625, 0.90625, 0.9140625, 0.904296875, 0.93359375, 0.9375, 0.9375, 0.951171875, 0.908203125, 0.9140625, 0.931640625, 0.935546875, 0.939453125, 0.931640625]
# [0.939453125, 0.943359375, 0.91015625, 0.90234375, 0.896484375, 0.89453125, 0.9296875, 0.923828125, 0.93359375, 0.951171875, 0.90625, 0.896484375, 0.9296875, 0.912109375, 0.923828125, 0.9375]

# %%
rf_mean_6 = statistics.mean(rf_acc_arr_6)
print("RF mean: ", rf_mean_6)
svm_mean_6 = statistics.mean(svm_acc_arr_6)
print("SVM mean: ", svm_mean_6)
knn_mean_6 = statistics.mean(knn_acc_arr_6)
print("kNN mean: ", knn_mean_6)

rf_acc_means.append(rf_mean_6)
svm_acc_means.append(svm_mean_6)
knn_acc_means.append(knn_mean_6)

rf_sadness_mean6 = statistics.mean(rf_sadness_arr_6)
print("RF mean: ", rf_sadness_mean6)
svm_sadness_mean6 = statistics.mean(svm_sadness_arr_6)
print("SVM mean: ", svm_sadness_mean6)
knn_sadness_mean6 = statistics.mean(knn_sadness_arr_6)
print("kNN mean: ", knn_sadness_mean6)

rf_sadness_means.append(rf_sadness_mean6)
svm_sadness_means.append(svm_sadness_mean6)
knn_sadness_means.append(knn_sadness_mean6)

rf_pleasure_mean6 = statistics.mean(rf_pleasure_arr_6)
print("RF mean: ", rf_pleasure_mean6)
svm_pleasure_mean6 = statistics.mean(svm_pleasure_arr_6)
print("SVM mean: ", svm_pleasure_mean6)
knn_pleasure_mean6 = statistics.mean(knn_pleasure_arr_6)
print("kNN mean: ", knn_pleasure_mean6)

rf_pleasure_means.append(rf_pleasure_mean6)
svm_pleasure_means.append(svm_pleasure_mean6)
knn_pleasure_means.append(knn_pleasure_mean6)

rf_anger_mean6 = statistics.mean(rf_anger_arr_6)
print("RF mean: ", rf_anger_mean6)
svm_anger_mean6 = statistics.mean(svm_anger_arr_6)
print("SVM mean: ", svm_anger_mean6)
knn_anger_mean6 = statistics.mean(knn_anger_arr_6)
print("kNN mean: ", knn_anger_mean6)

rf_anger_means.append(rf_anger_mean6)
svm_anger_means.append(svm_anger_mean6)
knn_anger_means.append(knn_anger_mean6)

rf_joy_mean6 = statistics.mean(rf_joy_arr_6)
print("RF mean: ", rf_joy_mean6)
svm_joy_mean6 = statistics.mean(svm_joy_arr_6)
print("SVM mean: ", svm_joy_mean6)
knn_joy_mean6 = statistics.mean(knn_joy_arr_6)
print("kNN mean: ", knn_joy_mean6)

rf_joy_means.append(rf_joy_mean6)
svm_joy_means.append(svm_joy_mean6)
knn_joy_means.append(knn_joy_mean6)
# Out:
# RF mean:  0.9271240234375
# SVM mean:  0.9276123046875
# kNN mean:  0.920654296875
# RF mean:  0.8499588616662689
# SVM mean:  0.847892362619971
# kNN mean:  0.8579463622609491
# RF mean:  0.8653690321565609
# SVM mean:  0.8594599412474699
# kNN mean:  0.8507654336262385
# RF mean:  0.9156543342720176
# SVM mean:  0.9158108342884197
# kNN mean:  0.8921179489776343
# RF mean:  0.9293664645242508
# SVM mean:  0.9305561347979364
# kNN mean:  0.9287965761106604

# %%
exp7_df
# Out:
#      Subject  Experiment ID Feature extraction Band selection  \
# 0          1              7               STFT      All bands
# 1          1              7               STFT      All bands
# 2          1              7               STFT      All bands
# 3          1              7               STFT      All bands
# 4          2              7               STFT      All bands
# ..       ...            ...                ...            ...
# 123       31              7               STFT      All bands
# 124       32              7               STFT      All bands
# 125       32              7               STFT      All bands
# 126       32              7               STFT      All bands
# 127       32              7               STFT      All bands
#
#     Channel selection Classification algorithm  Accuracy  Sadness precision  \
# 0          Literature            Random Forest  0.636719           0.543307
# ...

# %%
rf_lit_acc_arr = []
svm_lit_acc_arr = []
rf_own_acc_arr = []
svm_own_acc_arr = []

rf_lit_sadness_arr = []
svm_lit_sadness_arr = []
rf_own_sadness_arr = []
svm_own_sadness_arr = []

rf_lit_pleasure_arr = []
svm_lit_pleasure_arr = []
rf_own_pleasure_arr = []
svm_own_pleasure_arr = []

rf_lit_anger_arr = []
svm_lit_anger_arr = []
rf_own_anger_arr = []
svm_own_anger_arr = []

rf_lit_joy_arr = []
svm_lit_joy_arr = []
rf_own_joy_arr = []
svm_own_joy_arr = []

exp7_acc = exp7_df['Accuracy']
exp7_sadness = exp7_df['Sadness precision']
exp7_pleasure = exp7_df['Pleasure precision']
exp7_anger = exp7_df['Anger precision']
exp7_joy = exp7_df['Joy precision']

print(len(exp7_acc))
for i in range (0,len(exp7_acc)):
    if (i%4 == 0):
        rf_lit_acc_arr.append(exp7_acc[i])
        rf_lit_sadness_arr.append(exp7_sadness[i])
        rf_lit_pleasure_arr.append(exp7_pleasure[i])
        rf_lit_anger_arr.append(exp7_anger[i])
        rf_lit_joy_arr.append(exp7_joy[i])
    if (i%4 == 1):
        svm_lit_acc_arr.append(exp7_acc[i])
        svm_lit_sadness_arr.append(exp7_sadness[i])
        svm_lit_pleasure_arr.append(exp7_pleasure[i])
        svm_lit_anger_arr.append(exp7_anger[i])
        svm_lit_joy_arr.append(exp7_joy[i])
    if (i%4 == 2):
        rf_own_acc_arr.append(exp7_acc[i])
        rf_own_sadness_arr.append(exp7_sadness[i])
        rf_own_pleasure_arr.append(exp7_pleasure[i])
        rf_own_anger_arr.append(exp7_anger[i])
        rf_own_joy_arr.append(exp7_joy[i])
    if (i%4 == 3):
        svm_own_acc_arr.append(exp7_acc[i])
        svm_own_sadness_arr.append(exp7_sadness[i])
        svm_own_pleasure_arr.append(exp7_pleasure[i])
        svm_own_anger_arr.append(exp7_anger[i])
        svm_own_joy_arr.append(exp7_joy[i])


print(rf_lit_acc_arr)
print(svm_lit_acc_arr)
print(rf_own_acc_arr)
print(svm_own_acc_arr)
# Out:
# 128
# [0.63671875, 0.51953125, 0.666015625, 0.5625, 0.53125, 0.63671875, 0.564453125, 0.587890625, 0.603515625, 0.64453125, 0.53515625, 0.775390625, 0.68359375, 0.60546875, 0.716796875, 0.666015625, 0.56640625, 0.53515625, 0.62890625, 0.724609375, 0.677734375, 0.658203125, 0.775390625, 0.72265625, 0.654296875, 0.68359375, 0.626953125, 0.595703125, 0.546875, 0.611328125, 0.75, 0.677734375]
# [0.5234375, 0.5703125, 0.650390625, 0.419921875, 0.544921875, 0.58984375, 0.666015625, 0.556640625, 0.56640625, 0.505859375, 0.48828125, 0.705078125, 0.662109375, 0.5625, 0.515625, 0.505859375, 0.578125, 0.66015625, 0.59765625, 0.6875, 0.609375, 0.533203125, 0.611328125, 0.63671875, 0.61328125, 0.59375, 0.59765625, 0.537109375, 0.603515625, 0.6171875, 0.62890625, 0.71875]
# ...

# %%
rf_lit_mean = statistics.mean(rf_lit_acc_arr)
print("RF literature mean: ", rf_lit_mean)
svm_lit_mean = statistics.mean(svm_lit_acc_arr)
print("SVM literature mean: ", svm_lit_mean)
rf_own_mean = statistics.mean(rf_own_acc_arr)
print("RF own mean: ", rf_own_mean)
svm_own_mean = statistics.mean(svm_own_acc_arr)
print("SVM own mean: ", svm_own_mean)

rf_acc_means.append(rf_own_mean)
rf_acc_means.append(rf_lit_mean)

svm_acc_means.append(svm_own_mean)
svm_acc_means.append(svm_lit_mean)

knn_acc_means.append(None)
knn_acc_means.append(None)

rf_lit_sadness_mean = statistics.mean(rf_lit_sadness_arr)
print("RF literature mean: ", rf_lit_sadness_mean)
svm_lit_sadness_mean = statistics.mean(svm_lit_sadness_arr)
print("SVM literature mean: ", svm_lit_sadness_mean)
rf_own_sadness_mean = statistics.mean(rf_own_sadness_arr)
print("RF own mean: ", rf_own_sadness_mean)
svm_own_sadness_mean = statistics.mean(svm_own_sadness_arr)
print("SVM own mean: ", svm_own_sadness_mean)

rf_sadness_means.append(rf_own_sadness_mean)
rf_sadness_means.append(rf_lit_sadness_mean)

svm_sadness_means.append(svm_own_sadness_mean)
svm_sadness_means.append(svm_lit_sadness_mean)

knn_sadness_means.append(None)
knn_sadness_means.append(None)

rf_lit_pleasure_mean = statistics.mean(rf_lit_pleasure_arr)
print("RF literature mean: ", rf_lit_pleasure_mean)
svm_lit_pleasure_mean = statistics.mean(svm_lit_pleasure_arr)
print("SVM literature mean: ", svm_lit_pleasure_mean)
rf_own_pleasure_mean = statistics.mean(rf_own_pleasure_arr)
print("RF own mean: ", rf_own_pleasure_mean)
svm_own_pleasure_mean = statistics.mean(svm_own_pleasure_arr)
print("SVM own mean: ", svm_own_pleasure_mean)

rf_pleasure_means.append(rf_own_pleasure_mean)
rf_pleasure_means.append(rf_lit_pleasure_mean)

svm_pleasure_means.append(svm_own_pleasure_mean)
svm_pleasure_means.append(svm_lit_pleasure_mean)

knn_pleasure_means.append(None)
knn_pleasure_means.append(None)

rf_lit_anger_mean = statistics.mean(rf_lit_anger_arr)
print("RF literature mean: ", rf_lit_anger_mean)
svm_lit_anger_mean = statistics.mean(svm_lit_anger_arr)
print("SVM literature mean: ", svm_lit_anger_mean)
rf_own_anger_mean = statistics.mean(rf_own_anger_arr)
print("RF own mean: ", rf_own_anger_mean)
svm_own_anger_mean = statistics.mean(svm_own_anger_arr)
print("SVM own mean: ", svm_own_anger_mean)

rf_anger_means.append(rf_own_anger_mean)
rf_anger_means.append(rf_lit_anger_mean)

svm_anger_means.append(svm_own_anger_mean)
svm_anger_means.append(svm_lit_anger_mean)

knn_anger_means.append(None)
knn_anger_means.append(None)

rf_lit_joy_mean = statistics.mean(rf_lit_joy_arr)
print("RF literature mean: ", rf_lit_joy_mean)
svm_lit_joy_mean = statistics.mean(svm_lit_joy_arr)
print("SVM literature mean: ", svm_lit_joy_mean)
rf_own_joy_mean = statistics.mean(rf_own_joy_arr)
print("RF own mean: ", rf_own_joy_mean)
svm_own_joy_mean = statistics.mean(svm_own_joy_arr)
print("SVM own mean: ", svm_own_joy_mean)

rf_joy_means.append(rf_own_joy_mean)
rf_joy_means.append(rf_lit_joy_mean)

svm_joy_means.append(svm_own_joy_mean)
svm_joy_means.append(svm_lit_joy_mean)

knn_joy_means.append(None)
knn_joy_means.append(None)
# Out:
# RF literature mean:  0.6365966796875
# SVM literature mean:  0.58929443359375
# RF own mean:  0.67828369140625
# SVM own mean:  0.80999755859375
# RF literature mean:  0.3937490792977188
# SVM literature mean:  0.5939859456958344
# RF own mean:  0.4094668515388511
# SVM own mean:  0.8132454347128938
# RF literature mean:  0.5751591787538867
# SVM literature mean:  0.5795739060681809
# RF own mean:  0.5527202869732643
# SVM own mean:  0.799832787351039
# RF literature mean:  0.5491125921763893
# SVM literature mean:  0.605474565344595
# RF own mean:  0.49040404002993604
# SVM own mean:  0.8405111352960034
# RF literature mean:  0.6345288008152081
# SVM literature mean:  0.5914996387723087
# RF own mean:  0.6558511489871618
# SVM own mean:  0.8114238201477126

# %%
rf_lit_acc_arr = []
svm_lit_acc_arr = []
knn_lit_acc_arr = []
rf_own_acc_arr = []
svm_own_acc_arr = []
knn_own_acc_arr = []

rf_lit_sadness_arr = []
svm_lit_sadness_arr = []
knn_lit_sadness_arr = []
rf_own_sadness_arr = []
svm_own_sadness_arr = []
knn_own_sadness_arr = []

rf_lit_pleasure_arr = []
svm_lit_pleasure_arr = []
rf_own_pleasure_arr = []
svm_own_pleasure_arr = []
knn_lit_pleasure_arr = []
knn_own_pleasure_arr = []


rf_lit_anger_arr = []
svm_lit_anger_arr = []
rf_own_anger_arr = []
svm_own_anger_arr = []
knn_lit_anger_arr = []
knn_own_anger_arr = []

rf_lit_joy_arr = []
svm_lit_joy_arr = []
rf_own_joy_arr = []
svm_own_joy_arr = []
knn_lit_joy_arr = []
knn_own_joy_arr = []

exp7_acc = exp7_1_df['Accuracy']
exp7_sadness = exp7_1_df['Sadness precision']
exp7_pleasure = exp7_1_df['Pleasure precision']
exp7_anger = exp7_1_df['Anger precision']
exp7_joy = exp7_1_df['Joy precision']

print(len(exp7_acc))
for i in range (0,len(exp7_acc)):
    if (i%6 == 0):
        rf_lit_acc_arr.append(exp7_acc[i])
        rf_lit_sadness_arr.append(exp7_sadness[i])
        rf_lit_pleasure_arr.append(exp7_pleasure[i])
        rf_lit_anger_arr.append(exp7_anger[i])
        rf_lit_joy_arr.append(exp7_joy[i])
    if (i%6 == 1):
        svm_lit_acc_arr.append(exp7_acc[i])
        svm_lit_sadness_arr.append(exp7_sadness[i])
        svm_lit_pleasure_arr.append(exp7_pleasure[i])
        svm_lit_anger_arr.append(exp7_anger[i])
        svm_lit_joy_arr.append(exp7_joy[i])
    if (i%6 == 2):
        knn_lit_acc_arr.append(exp7_acc[i])
        knn_lit_sadness_arr.append(exp7_sadness[i])
        knn_lit_pleasure_arr.append(exp7_pleasure[i])
        knn_lit_anger_arr.append(exp7_anger[i])
        knn_lit_joy_arr.append(exp7_joy[i])
    if (i%6 == 3):
        rf_own_acc_arr.append(exp7_acc[i])
        rf_own_sadness_arr.append(exp7_sadness[i])
        rf_own_pleasure_arr.append(exp7_pleasure[i])
        rf_own_anger_arr.append(exp7_anger[i])
        rf_own_joy_arr.append(exp7_joy[i])
    if (i%6 == 4):
        svm_own_acc_arr.append(exp7_acc[i])
        svm_own_sadness_arr.append(exp7_sadness[i])
        svm_own_pleasure_arr.append(exp7_pleasure[i])
        svm_own_anger_arr.append(exp7_anger[i])
        svm_own_joy_arr.append(exp7_joy[i])
    if (i%6 == 5):
        knn_own_acc_arr.append(exp7_acc[i])
        knn_own_sadness_arr.append(exp7_sadness[i])
        knn_own_pleasure_arr.append(exp7_pleasure[i])
        knn_own_anger_arr.append(exp7_anger[i])
        knn_own_joy_arr.append(exp7_joy[i])

print(rf_lit_acc_arr)
print(svm_lit_acc_arr)
print(rf_own_acc_arr)
print(svm_own_acc_arr)

rf_lit_mean = statistics.mean(rf_lit_acc_arr)
print("RF literature mean: ", rf_lit_mean)
svm_lit_mean = statistics.mean(svm_lit_acc_arr)
print("SVM literature mean: ", svm_lit_mean)
rf_own_mean = statistics.mean(rf_own_acc_arr)
print("RF own mean: ", rf_own_mean)
svm_own_mean = statistics.mean(svm_own_acc_arr)
print("SVM own mean: ", svm_own_mean)
knn_lit_mean = statistics.mean(knn_lit_acc_arr)
print("knn literature mean: ", knn_lit_mean)
knn_own_mean = statistics.mean(knn_own_acc_arr)
print("knn own mean: ", knn_own_mean)

rf_acc_means.append(rf_own_mean)
rf_acc_means.append(rf_lit_mean)

svm_acc_means.append(svm_own_mean)
svm_acc_means.append(svm_lit_mean)

knn_acc_means.append(knn_own_mean)
knn_acc_means.append(knn_lit_mean)

rf_lit_sadness_mean = statistics.mean(rf_lit_sadness_arr)
print("RF literature mean: ", rf_lit_sadness_mean)
svm_lit_sadness_mean = statistics.mean(svm_lit_sadness_arr)
print("SVM literature mean: ", svm_lit_sadness_mean)
rf_own_sadness_mean = statistics.mean(rf_own_sadness_arr)
print("RF own mean: ", rf_own_sadness_mean)
svm_own_sadness_mean = statistics.mean(svm_own_sadness_arr)
print("SVM own mean: ", svm_own_sadness_mean)
knn_lit_sadness_mean = statistics.mean(knn_lit_sadness_arr)
print("knn literature mean: ", knn_lit_sadness_mean)
knn_own_sadness_mean = statistics.mean(knn_own_sadness_arr)
print("knn own mean: ", knn_own_sadness_mean)

rf_sadness_means.append(rf_own_sadness_mean)
rf_sadness_means.append(rf_lit_sadness_mean)

svm_sadness_means.append(svm_own_sadness_mean)
svm_sadness_means.append(svm_lit_sadness_mean)

knn_sadness_means.append(knn_own_sadness_mean)
knn_sadness_means.append(knn_lit_sadness_mean)

rf_lit_pleasure_mean = statistics.mean(rf_lit_pleasure_arr)
print("RF literature mean: ", rf_lit_pleasure_mean)
svm_lit_pleasure_mean = statistics.mean(svm_lit_pleasure_arr)
print("SVM literature mean: ", svm_lit_pleasure_mean)
rf_own_pleasure_mean = statistics.mean(rf_own_pleasure_arr)
print("RF own mean: ", rf_own_pleasure_mean)
svm_own_pleasure_mean = statistics.mean(svm_own_pleasure_arr)
print("SVM own mean: ", svm_own_pleasure_mean)
knn_lit_pleasure_mean = statistics.mean(knn_lit_pleasure_arr)
print("knn literature mean: ", knn_lit_pleasure_mean)
knn_own_pleasure_mean = statistics.mean(knn_own_pleasure_arr)
print("knn own mean: ", knn_own_pleasure_mean)

rf_pleasure_means.append(rf_own_pleasure_mean)
rf_pleasure_means.append(rf_lit_pleasure_mean)

svm_pleasure_means.append(svm_own_pleasure_mean)
svm_pleasure_means.append(svm_lit_pleasure_mean)

knn_pleasure_means.append(knn_own_pleasure_mean)
knn_pleasure_means.append(knn_lit_pleasure_mean)

rf_lit_anger_mean = statistics.mean(rf_lit_anger_arr)
print("RF literature mean: ", rf_lit_anger_mean)
svm_lit_anger_mean = statistics.mean(svm_lit_anger_arr)
print("SVM literature mean: ", svm_lit_anger_mean)
rf_own_anger_mean = statistics.mean(rf_own_anger_arr)
print("RF own mean: ", rf_own_anger_mean)
svm_own_anger_mean = statistics.mean(svm_own_anger_arr)
print("SVM own mean: ", svm_own_anger_mean)
knn_lit_anger_mean = statistics.mean(knn_lit_anger_arr)
print("knn literature mean: ", knn_lit_anger_mean)
knn_own_anger_mean = statistics.mean(knn_own_anger_arr)
print("knn own mean: ", knn_own_anger_mean)

rf_anger_means.append(rf_own_anger_mean)
rf_anger_means.append(rf_lit_anger_mean)

svm_anger_means.append(svm_own_anger_mean)
svm_anger_means.append(svm_lit_anger_mean)

knn_anger_means.append(knn_own_anger_mean)
knn_anger_means.append(knn_lit_anger_mean)

rf_lit_joy_mean = statistics.mean(rf_lit_joy_arr)
print("RF literature mean: ", rf_lit_joy_mean)
svm_lit_joy_mean = statistics.mean(svm_lit_joy_arr)
print("SVM literature mean: ", svm_lit_joy_mean)
rf_own_joy_mean = statistics.mean(rf_own_joy_arr)
print("RF own mean: ", rf_own_joy_mean)
svm_own_joy_mean = statistics.mean(svm_own_joy_arr)
print("SVM own mean: ", svm_own_joy_mean)
knn_lit_joy_mean = statistics.mean(knn_lit_joy_arr)
print("knn literature mean: ", knn_lit_joy_mean)
knn_own_joy_mean = statistics.mean(knn_own_joy_arr)
print("knn own mean: ", knn_own_joy_mean)

rf_joy_means.append(rf_own_joy_mean)
rf_joy_means.append(rf_lit_joy_mean)

svm_joy_means.append(svm_own_joy_mean)
svm_joy_means.append(svm_lit_joy_mean)

knn_joy_means.append(knn_own_joy_mean)
knn_joy_means.append(knn_lit_joy_mean)
# Out:
# 180
# [0.916015625, 0.939453125, 0.947265625, 0.91015625, 0.927734375, 0.890625, 0.88671875, 0.8984375, 0.896484375, 0.90625, 0.951171875, 0.93359375, 0.947265625, 0.9375, 0.892578125, 0.9375, 0.90625, 0.951171875, 0.951171875, 0.908203125, 0.9140625, 0.9375, 0.931640625, 0.908203125, 0.919921875, 0.91015625, 0.9296875, 0.916015625, 0.931640625, 0.92578125]
# [0.853515625, 0.939453125, 0.818359375, 0.716796875, 0.736328125, 0.642578125, 0.59375, 0.693359375, 0.6328125, 0.6328125, 0.87109375, 0.70703125, 0.72265625, 0.634765625, 0.59765625, 0.703125, 0.681640625, 0.76953125, 0.7265625, 0.73828125, 0.5859375, 0.66796875, 0.7578125, 0.662109375, 0.693359375, 0.703125, 0.744140625, 0.708984375, 0.716796875, 0.7890625]
# ...

# %%
'''
print(len(rf_acc_means))
print(len(svm_acc_means))
print(len(knn_acc_means))

print(len(rf_sadness_means))
print(len(svm_sadness_means))
print(len(knn_sadness_means))

print(len(rf_pleasure_means))
print(len(svm_pleasure_means))
print(len(knn_pleasure_means))

print(len(rf_anger_means))
print(len(svm_anger_means))
print(len(knn_anger_means))

print(len(rf_joy_means))
print(len(svm_joy_means))
print(len(knn_joy_means))
'''
# Out:
# '\nprint(len(rf_acc_means))\nprint(len(svm_acc_means))\nprint(len(knn_acc_means))\n\nprint(len(rf_sadness_means))\nprint(len(svm_sadness_means))\nprint(len(knn_sadness_means))\n\nprint(len(rf_pleasure_means))\nprint(len(svm_pleasure_means))\nprint(len(knn_pleasure_means))\n\nprint(len(rf_anger_means))\nprint(len(svm_anger_means))\nprint(len(knn_anger_means))\n\nprint(len(rf_joy_means))\nprint(len(svm_joy_means))\nprint(len(knn_joy_means))\n'

# %%
data = {'RF': rf_acc_means, 'SVM': svm_acc_means, 'kNN': knn_acc_means, 'RF sadness': rf_sadness_means, 'SVM sadness': svm_sadness_means, 'kNN sadness': knn_sadness_means,  'RF pleasure': rf_pleasure_means, 'SVM pleasure': svm_pleasure_means, 'kNN pleasure': knn_pleasure_means, 'RF anger': rf_anger_means, 'SVM anger': svm_anger_means, 'kNN anger': knn_anger_means,  'RF joy': rf_joy_means, 'SVM joy': svm_joy_means, 'kNN joy': knn_joy_means}
df = pd.DataFrame(data)
df.index = ['Experiment 5 Delta', 'Experiment 5 Theta', 'Experiment 5 Alpha', 'Experiment 5 Beta', 'Experiment 5 Gamma', 'Experiment 5_1 Delta', 'Experiment 5_1 Theta', 'Experiment 5_1 Alpha', 'Experiment 5_1 Beta', 'Experiment 5_1 Gamma', 'Experiment 6 (All bands)', 'Experiment 6_1 (All bands)', 'Experiment 7 Own', 'Experiment 7 Literature', 'Experiment 7_1 Own', 'Experiment 7_1 Literature']
df
# Out:
#                                   RF       SVM       kNN  RF sadness  \
# Experiment 5 Delta          0.618042  0.465332  0.910950    0.537756
# Experiment 5 Theta          0.641418  0.465027  0.913696    0.420922
# Experiment 5 Alpha          0.645874  0.464783  0.911804    0.445617
# Experiment 5 Beta           0.635986  0.837097  0.912354    0.288895
# Experiment 5 Gamma          0.633850  0.873169  0.912903    0.407889
# Experiment 5_1 Delta        0.912500  0.507682  0.915820    0.857710
# Experiment 5_1 Theta        0.922591  0.518294  0.917122    0.862942
# Experiment 5_1 Alpha        0.925065  0.576432  0.916536    0.854063
# Experiment 5_1 Beta         0.922266  0.917578  0.914323    0.859971
# Experiment 5_1 Gamma        0.922656  0.917578  0.916081    0.850096
# Experiment 6 (All bands)    0.675903  0.913452  0.918091    0.583504
# Experiment 6_1 (All bands)  0.927124  0.927612  0.920654    0.849959
# Experiment 7 Own            0.678284  0.809998       NaN    0.409467
# ...
