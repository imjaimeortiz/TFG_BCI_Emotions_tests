# %%
import pandas as pd
import statistics
import numpy as np
from statistics import mean


#exp1_df
exp2_df = pd.read_csv("Experiment2.csv")
exp3_df = pd.read_csv("Experiment3.csv")
exp4_df = pd.read_csv("Experiment4.csv")

# %%
rf_means = []
svm_means = []
knn_means = []

# %%
exp2_df
# Out:
#      Subject  Experiment ID Feature extraction Band selection  \
# 0          1              2               STFT          Delta
# 1          1              2               STFT          Delta
# 2          1              2               STFT          Delta
# 3          1              2               STFT          Theta
# 4          1              2               STFT          Theta
# ..       ...            ...                ...            ...
# 460       32              2               STFT           Beta
# 461       32              2               STFT           Beta
# 462       32              2               STFT          Gamma
# 463       32              2               STFT          Gamma
# 464       32              2               STFT          Gamma
#
#     Channel selection Classification algorithm  Accuracy  Happy precision  \
# 0                   -            Random Forest  0.833984         0.937500
# ...

# %%
rf_acc_arr_delta = []
svm_acc_arr_delta = []
knn_acc_arr_delta = []
rf_acc_arr_theta = []
svm_acc_arr_theta = []
knn_acc_arr_theta = []
rf_acc_arr_alpha = []
svm_acc_arr_alpha = []
knn_acc_arr_alpha = []
rf_acc_arr_beta = []
svm_acc_arr_beta = []
knn_acc_arr_beta = []
rf_acc_arr_gamma = []
svm_acc_arr_gamma = []
knn_acc_arr_gamma = []

exp2_acc = exp2_df['Sad precision']

print(len(exp2_acc))
for i in range (0,len(exp2_acc)):
    if (i%15 == 0):
        rf_acc_arr_delta.append(exp2_acc[i])
    if (i%15 == 1):
        svm_acc_arr_delta.append(exp2_acc[i])
    if (i%15 == 2):
        knn_acc_arr_delta.append(exp2_acc[i])
    if (i%15 == 3):
        rf_acc_arr_theta.append(exp2_acc[i])
    if (i%15 == 4):
        svm_acc_arr_theta.append(exp2_acc[i])
    if (i%15 == 5):
        knn_acc_arr_theta.append(exp2_acc[i])
    if (i%15 == 6):
        rf_acc_arr_alpha.append(exp2_acc[i])
    if (i%15 == 7):
        svm_acc_arr_alpha.append(exp2_acc[i])
    if (i%15 == 8):
        knn_acc_arr_alpha.append(exp2_acc[i])
    if (i%15 == 9):
        rf_acc_arr_beta.append(exp2_acc[i])
    if (i%15 == 10):
        svm_acc_arr_beta.append(exp2_acc[i])
    if (i%15 == 11):
        knn_acc_arr_beta.append(exp2_acc[i])
    if (i%15 == 12):
        rf_acc_arr_gamma.append(exp2_acc[i])
    if (i%15 == 13):
        svm_acc_arr_gamma.append(exp2_acc[i])
    if (i%15 == 14):
        knn_acc_arr_gamma.append(exp2_acc[i])
# Out:
# 465

# %%
rf_mean_delta = statistics.mean(rf_acc_arr_delta)
print("RF mean delta: ", rf_mean_delta)
svm_mean_delta = statistics.mean(svm_acc_arr_delta)
print("SVM mean delta: ", svm_mean_delta)
knn_mean_delta = statistics.mean(knn_acc_arr_delta)
print("kNN mean delta: ",knn_mean_delta)

rf_mean_theta = statistics.mean(rf_acc_arr_theta)
print("RF mean theta: ", rf_mean_theta)
svm_mean_theta = statistics.mean(svm_acc_arr_theta)
print("SVM mean theta: ", svm_mean_theta)
knn_mean_theta = statistics.mean(knn_acc_arr_theta)
print("kNN mean theta: ",knn_mean_theta)

rf_mean_alpha = statistics.mean(rf_acc_arr_alpha)
print("RF mean alpha: ", rf_mean_alpha)
svm_mean_alpha = statistics.mean(svm_acc_arr_alpha)
print("SVM mean alpha: ", svm_mean_alpha)
knn_mean_alpha = statistics.mean(knn_acc_arr_alpha)
print("kNN mean alpha: ",knn_mean_alpha)

rf_mean_beta = statistics.mean(rf_acc_arr_beta)
print("RF mean beta: ", rf_mean_beta)
svm_mean_beta = statistics.mean(svm_acc_arr_beta)
print("SVM mean beta: ", svm_mean_beta)
knn_mean_beta = statistics.mean(knn_acc_arr_beta)
print("kNN mean beta: ",knn_mean_beta)

rf_mean_gamma = statistics.mean(rf_acc_arr_gamma)
print("RF mean gamma: ", rf_mean_gamma)
svm_mean_gamma = statistics.mean(svm_acc_arr_gamma)
print("SVM mean gamma: ", svm_mean_gamma)
knn_mean_gamma = statistics.mean(knn_acc_arr_gamma)
print("kNN mean gamma: ",knn_mean_gamma)

rf_means.append(rf_mean_delta)
rf_means.append(rf_mean_theta)
rf_means.append(rf_mean_alpha)
rf_means.append(rf_mean_beta)
rf_means.append(rf_mean_gamma)

svm_means.append(svm_mean_delta)
svm_means.append(svm_mean_theta)
svm_means.append(svm_mean_alpha)
svm_means.append(svm_mean_beta)
svm_means.append(svm_mean_gamma)

knn_means.append(knn_mean_delta)
knn_means.append(knn_mean_theta)
knn_means.append(knn_mean_alpha)
knn_means.append(knn_mean_beta)
knn_means.append(knn_mean_gamma)
# Out:
# RF mean delta:  0.8088236536055076
# SVM mean delta:  0.6863362193775437
# kNN mean delta:  0.9588113365224631
# RF mean theta:  0.8197332500418567
# SVM mean theta:  0.7105412870059623
# kNN mean theta:  0.9532834945836633
# RF mean alpha:  0.8163304223384138
# SVM mean alpha:  0.6789683154347085
# kNN mean alpha:  0.9535344166420152
# RF mean beta:  0.8189637055882864
# SVM mean beta:  0.8547961934061656
# kNN mean beta:  0.9499859040748001
# RF mean gamma:  0.8129842558395654
# SVM mean gamma:  0.856564774767484
# kNN mean gamma:  0.9576727022242405

# %%
exp3_df
# Out:
#     Subject  Experiment ID Feature extraction Band selection  \
# 0         1              3               STFT      All bands
# 1         1              3               STFT      All bands
# 2         1              3               STFT      All bands
# 3         2              3               STFT      All bands
# 4         2              3               STFT      All bands
# ..      ...            ...                ...            ...
# 91       31              3               STFT      All bands
# 92       31              3               STFT      All bands
# 93       32              3               STFT      All bands
# 94       32              3               STFT      All bands
# 95       32              3               STFT      All bands
#
#    Channel selection Classification algorithm  Accuracy  Happy precision  \
# 0                  -            Random Forest  0.966797         0.954918
# 1                  -                      SVM  0.960938         0.969957
# ...

# %%
rf_acc_arr_3 = []
svm_acc_arr_3 = []
knn_acc_arr_3 = []
exp3_acc = exp3_df['Sad precision']

print(len(exp3_acc))
for i in range (0,len(exp3_acc)):
    if (i%3 == 0):
        rf_acc_arr_3.append(exp3_acc[i])
    if (i%3 == 1):
        svm_acc_arr_3.append(exp3_acc[i])
    if (i%3 == 2):
        knn_acc_arr_3.append(exp3_acc[i])

print(rf_acc_arr_3)
print(svm_acc_arr_3)
print(knn_acc_arr_3)
# Out:
# 96
# [0.9549180327868853, 0.75, 0.8832116788321168, 0.9285714285714286, 0.847953216374269, 0.8374164810690423, 0.8730964467005076, 0.9083333333333332, 0.8760330578512396, 0.9198473282442748, 0.6984478935698448, 0.9457364341085271, 0.9293478260869564, 0.8313253012048193, 0.932642487046632, 0.8228571428571428, 0.9064516129032258, 0.8510028653295129, 0.8761061946902655, 0.8819875776397516, 0.8736842105263158, 0.8954248366013072, 0.9068493150684932, 0.9068493150684932, 0.8793774319066148, 0.8235294117647058, 0.8603603603603603, 0.8093994778067886, 0.8651315789473685, 0.7863636363636364, 0.8728323699421965, 0.823943661971831]
# ...

# %%
rf_mean_3 = statistics.mean(rf_acc_arr_3)
print("RF mean: ", rf_mean_3)
svm_mean_3 = statistics.mean(svm_acc_arr_3)
print("SVM mean: ", svm_mean_3)
knn_mean_3 = statistics.mean(knn_acc_arr_3)
print("kNN mean: ", knn_mean_3)

rf_means.append(rf_mean_3)
svm_means.append(rf_mean_3)
knn_means.append(rf_mean_3)
# Out:
# RF mean:  0.8674697482977465
# SVM mean:  0.9608266373422103
# kNN mean:  0.9557224579215032

# %%
exp4_df
# Out:
#      Subject  Experiment ID Feature extraction Band selection  \
# 0          1              4               STFT      All bands
# 1          1              4               STFT      All bands
# 2          1              4               STFT      All bands
# 3          1              4               STFT      All bands
# 4          2              4               STFT      All bands
# ..       ...            ...                ...            ...
# 123       31              4               STFT      All bands
# 124       32              4               STFT      All bands
# 125       32              4               STFT      All bands
# 126       32              4               STFT      All bands
# 127       32              4               STFT      All bands
#
#     Channel selection Classification algorithm  Accuracy  Happy precision  \
# 0          Literature            Random Forest  0.910156         0.893878
# ...

# %%
rf_lit_acc_arr = []
svm_lit_acc_arr = []
rf_own_acc_arr = []
svm_own_acc_arr = []
exp4_acc = exp4_df['Sad precision']

print(len(exp4_acc))
for i in range (0,len(exp4_acc)):
    if (i%4 == 0):
        rf_lit_acc_arr.append(exp4_acc[i])
    if (i%4 == 1):
        svm_lit_acc_arr.append(exp4_acc[i])
    if (i%4 == 2):
        rf_own_acc_arr.append(exp4_acc[i])
    if (i%4 == 3):
        svm_own_acc_arr.append(exp4_acc[i])


print(rf_lit_acc_arr)
print(svm_lit_acc_arr)
print(rf_own_acc_arr)
print(svm_own_acc_arr)
# Out:
# 128
# [0.8938775510204081, 0.6954022988505747, 0.8214285714285714, 0.9306930693069309, 0.8715953307392996, 0.8600917431192661, 0.7995391705069125, 0.9071729957805909, 0.7550335570469798, 0.7747440273037542, 0.6892778993435449, 0.8555133079847909, 0.98, 0.7902621722846442, 0.8125, 0.8571428571428571, 0.7902298850574713, 0.7664041994750657, 0.7741935483870968, 0.8554216867469879, 0.8709677419354839, 0.8910256410256411, 0.8491620111731844, 0.717948717948718, 0.7781954887218046, 0.7881773399014779, 0.7860082304526749, 0.7611940298507462, 0.7637540453074434, 0.7780269058295964, 0.8228882833787466, 0.782608695652174]
# ...

# %%
rf_lit_mean = statistics.mean(rf_lit_acc_arr)
print("RF literature mean: ", rf_lit_mean)
svm_lit_mean = statistics.mean(svm_lit_acc_arr)
print("SVM literature mean: ", svm_lit_mean)
rf_own_mean = statistics.mean(rf_own_acc_arr)
print("RF own mean: ", rf_own_mean)
svm_own_mean = statistics.mean(svm_own_acc_arr)
print("SVM own mean: ", svm_own_mean)

rf_means.append(rf_own_mean)
rf_means.append(rf_lit_mean)

svm_means.append(svm_own_mean)
svm_means.append(svm_lit_mean)

knn_means.append(None)
knn_means.append(None)
# Out:
# RF literature mean:  0.8147025313344824
# SVM literature mean:  0.7256177619253861
# RF own mean:  0.8490550078852602
# SVM own mean:  0.9085075746965132

# %%
data = {'RF': rf_means, 'SVM': svm_means, 'kNN': knn_means}
df = pd.DataFrame(data)
df.index = ['Experiment 2 Delta', 'Experiment 2 Theta', 'Experiment 2 Alpha', 'Experiment 2 Beta', 'Experiment 2 Gamma', 'Experiment 3 (All bands)', 'Experiment 4 Own', 'Experiment 4 Literature']
print(df)
# Out:
#                                 RF       SVM       kNN
# Experiment 2 Delta        0.788747  0.591734  0.947455
# Experiment 2 Theta        0.813382  0.590159  0.947959
# Experiment 2 Alpha        0.814327  0.590159  0.948274
# Experiment 2 Beta         0.806641  0.852760  0.948652
# Experiment 2 Gamma        0.816973  0.861202  0.950542
# Experiment 3 (All bands)  0.874084  0.874084  0.874084
# Experiment 4 Own          0.854309  0.903625       NaN
# Experiment 4 Literature   0.816467  0.722595       NaN
# Experiment 5 Delta        0.618042  0.465332  0.910950
# Experiment 5 Theta        0.641418  0.465027  0.913696
# Experiment 5 Alpha        0.645874  0.464783  0.911804
# Experiment 5 Beta         0.635986  0.837097  0.912354
# Experiment 5 Gamma        0.633850  0.873169  0.912903
# Experiment 6 (All bands)  0.680359  0.680359  0.680359
